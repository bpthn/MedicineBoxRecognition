# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.66-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.6.15)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# Downloading roboflow-1.1.66-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 4.8 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 44.6 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.4 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.1.1 roboflow-1.1.66

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3j9KnCrn3vCKxbGLZmCp")
project = rf.workspace("medi-nxjbd").project("medicineboxes-nmmta")
version = project.version(10)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in MedicineBoxes-10 to coco:: 100%|██████████| 43589/43589 [00:00<00:00, 82708.66it/s]
# Extracting Dataset Version Zip to MedicineBoxes-10 in coco:: 100%|██████████| 1466/1466 [00:00<00:00, 6839.08it/s]

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
import os
import torchvision
import torch
from PIL import Image
import numpy as np
from torch.utils.data import DataLoader
from torch.utils.data import Subset
import random
import json
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
def convert_bbox_tocrop(box):
    """function convert bbox from annotation or prediction
    bbox format = [x_min, y_min, width, height]
    crop area = [x_min, y_min, x_max, y_max]
    input box: list
    return crop_area: list
    """
    x_min = box[0]
    y_min = box[1]
    width = box[2]
    height = box[3]
    x_max = x_min + width
    y_max = y_min + height
    crop_area = [x_min, y_min, x_max, y_max]
    return crop_area



# Custom collate function for batching
def coco_collate_fn(batch):
    images, targets = zip(*batch)

    images = torch.stack(images, 0)
    targets = torch.cat(targets, 0)
    return images, targets

# Randomly sample 20% of the dataset indices
def get_subset(dataset, percentage):
    total_size = len(dataset)
    subset_size = int(total_size * percentage)
    indices = random.sample(range(total_size), subset_size)
    return Subset(dataset, indices)

# %%
import json

def convert_user_tags_to_annotations(json_path, output_path):
    with open(json_path, 'r') as f:
        coco_data = json.load(f)

    # 1. Map user_tag to category_id
    tag_to_id = {}
    new_categories = []
    new_annotations = []
    next_ann_id = 1
    next_cat_id = 0

    for image in coco_data['images']:
        user_tags = image.get('extra', {}).get('user_tags', [])

        if user_tags and isinstance(user_tags, list) and user_tags[0]:
            tag = user_tags[0]
        else:
            continue


        if tag not in tag_to_id:
            tag_to_id[tag] = next_cat_id
            new_categories.append({
                "id": next_cat_id,
                "name": tag
            })
            next_cat_id += 1

        # Add annotation
        new_annotations.append({
            "id": next_ann_id,
            "image_id": image['id'],
            "category_id": tag_to_id[tag]
        })
        next_ann_id += 1


    coco_data['annotations'] = new_annotations
    coco_data['categories'] = new_categories


    with open(output_path, 'w') as f:
        json.dump(coco_data, f, indent=4)

    print(f"Updated annotation file saved to: {output_path}")

# %%
# dataset = os.path.join(HOME, 'MedicineBoxes-2')
dataset = 'MedicineBoxes-10'
# Settings
ANNOTATION_FILE_NAME = "_annotations.coco.json"
TRAIN_DIRECTORY = os.path.join(dataset, "train")
VAL_DIRECTORY = os.path.join(dataset, "valid")
TEST_DIRECTORY = os.path.join(dataset, "test")

convert_user_tags_to_annotations(
    json_path= os.path.join(TRAIN_DIRECTORY, ANNOTATION_FILE_NAME),
    output_path=os.path.join(TRAIN_DIRECTORY,'_new_annotations_8classes.coco.json')
)
convert_user_tags_to_annotations(
    json_path= os.path.join(VAL_DIRECTORY, ANNOTATION_FILE_NAME),
    output_path=os.path.join(VAL_DIRECTORY,'_new_annotations_8classes.coco.json')
)
convert_user_tags_to_annotations(
    json_path= os.path.join(TEST_DIRECTORY, ANNOTATION_FILE_NAME),
    output_path=os.path.join(TEST_DIRECTORY,'_new_annotations_8classes.coco.json')
)
# Out:
# Updated annotation file saved to: MedicineBoxes-10/train/_new_annotations_8classes.coco.json
# Updated annotation file saved to: MedicineBoxes-10/valid/_new_annotations_8classes.coco.json
# Updated annotation file saved to: MedicineBoxes-10/test/_new_annotations_8classes.coco.json

# %%
output_path = os.path.join(TRAIN_DIRECTORY,'_new_annotations_8classes.coco.json')

# %%
# Path to your annotation file
annotation_file = output_path

# Load the annotation file
with open(annotation_file, 'r') as f:
    coco_data = json.load(f)

# Create a mapping of category_id to category_name
category_id_to_name = {category['id']: category['name'] for category in coco_data['categories']}
name_to_category_id = {v: k for k, v in category_id_to_name.items()}

# Example: Print the mapping
print("Category Mapping:", category_id_to_name)
# Out:
# Category Mapping: {0: 'Antihypertensives', 1: 'Antiplatelet-Agents', 2: 'Nitrates', 3: 'Anticoagulants', 4: 'Antiarrhythmics', 5: 'Statins', 6: 'Heart-Failure-Medications', 7: 'Combination-Medications'}

# %%
import json
from collections import defaultdict
train_anno_path = os.path.join(TRAIN_DIRECTORY,'_new_annotations_8classes.coco.json')
test_anno_path = os.path.join(TEST_DIRECTORY,'_new_annotations_8classes.coco.json')
val_anno_path = os.path.join(VAL_DIRECTORY,'_new_annotations_8classes.coco.json')

# Load COCO annotation JSON file
with open(test_anno_path, 'r') as f:
    coco = json.load(f)

# Map category_id to category_name
categories = {cat['id']: cat['name'] for cat in coco['categories']}

# Dictionary to hold unique image ids per category
images_per_category = defaultdict(set)

# Loop through annotations and collect image ids per category
for ann in coco['annotations']:
    category_id = ann['category_id']
    image_id = ann['image_id']
    images_per_category[category_id].add(image_id)

# Count images per category
for category_id, image_ids in images_per_category.items():
    print(f"Category '{categories[category_id]}' has {len(image_ids)} images")
# Out:
# Category 'Antihypertensives' has 45 images
# Category 'Combination-Medications' has 6 images
# Category 'Antiarrhythmics' has 8 images
# Category 'Anticoagulants' has 16 images
# Category 'Statins' has 29 images
# Category 'Heart-Failure-Medications' has 9 images
# Category 'Nitrates' has 10 images
# Category 'Antiplatelet-Agents' has 11 images

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import os
from PIL import Image

# Custom Dataset Class
class CocoClassificationDataset(torchvision.datasets.CocoDetection):
    def __init__(self, image_directory_path: str, img_height=32, img_width=100, train=True, transform=None):
        annotation_file_path = os.path.join(image_directory_path, ANNOTATION_FILE_NAME)
        super(CocoClassificationDataset, self).__init__(image_directory_path, annotation_file_path)
        self.img_height = img_height
        self.img_width = img_width
        self.transform = transform  # Store transform

    def __getitem__(self, idx):
        # Get image and annotations using the parent class
        image, annotations = super(CocoClassificationDataset, self).__getitem__(idx)

        if annotations and 'bbox' in annotations[0]:
            bbox = annotations[0]['bbox']
            crop_bbox = convert_bbox_tocrop(bbox)
            image = image.crop(crop_bbox)

        if self.transform:
            image = self.transform(image)

        if annotations and 'category_id' in annotations[0]:
            class_label = annotations[0]['category_id']
            target = torch.tensor(class_label, dtype=torch.long)
            return image, target
        else:
            return None

# Custom collate function for batching
def coco_collate_fn(batch):
    batch = [b for b in batch if b is not None]
    if not batch:
        return torch.empty(0), torch.empty(0, dtype=torch.long)

    images, targets = zip(*batch)
    images = torch.stack(images, 0)
    targets = torch.tensor(targets, dtype=torch.long)
    return images, targets

# %%
# dataset = os.path.join(HOME, 'MedicineBoxes-2')
dataset = 'MedicineBoxes-10'
# Settings
ANNOTATION_FILE_NAME = "_new_annotations_8classes.coco.json"
# ANNOTATION_FILE_NAME = "_annotations.coco.json"
TRAIN_DIRECTORY = os.path.join(dataset, "train")
VAL_DIRECTORY = os.path.join(dataset, "valid")
TEST_DIRECTORY = os.path.join(dataset, "test")


# Define data augmentation for training


train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.1, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])




# Validation/Test transformations (NO augmentation)
val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])




# Load datasets
train_dataset = CocoClassificationDataset(TRAIN_DIRECTORY, transform=train_transform)
val_dataset = CocoClassificationDataset(VAL_DIRECTORY, transform=val_test_transform)
test_dataset = CocoClassificationDataset(TEST_DIRECTORY, transform=val_test_transform)


from torch.utils.data import WeightedRandomSampler
labels = []
for item in train_dataset:
    if item is not None:
        _, label = item
        labels.append(label.item())
train_labels_array = np.array(labels)

# Compute class counts
class_counts = np.bincount(train_labels_array)
weights = 1. / class_counts
sample_weights = weights[train_labels_array]

sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)



# DataLoaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, num_workers=2, collate_fn=coco_collate_fn, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=coco_collate_fn)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=coco_collate_fn)
# Check dataset sizes
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(val_dataset))
print("Number of validation examples:", len(test_dataset))
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Number of training examples: 925
# Number of validation examples: 393
# Number of validation examples: 140

# %%
# Path to your annotation file
annotation_file = os.path.join(TRAIN_DIRECTORY, ANNOTATION_FILE_NAME)

# Load the annotation file
with open(annotation_file, 'r') as f:
    coco_data = json.load(f)

# Create a mapping of category_id to category_name
category_id_to_name = {category['id']: category['name'] for category in coco_data['categories']}
name_to_category_id = {v: k for k, v in category_id_to_name.items()}

# Example: Print the mapping
print("Category Mapping:", category_id_to_name)
# Out:
# Category Mapping: {0: 'Antihypertensives', 1: 'Antiplatelet-Agents', 2: 'Nitrates', 3: 'Anticoagulants', 4: 'Antiarrhythmics', 5: 'Statins', 6: 'Heart-Failure-Medications', 7: 'Combination-Medications'}

# %%
## Library

# %% [markdown]
# ## Function

# %%
def show_image_with_label(image, label):
    """Display image with its readable label."""
    image = image.numpy().transpose((1, 2, 0))  # Convert (C, H, W) -> (H, W, C)
    image = (image + 1.0) / 2.0  # De-normalize from [-1, 1] to [0, 1]
    image = np.clip(image, 0, 1)  # Clip values to valid range
    plt.imshow(image)
    plt.title(f"Label: {label} {category_id_to_name.get(int(label))}")
    plt.axis("off")
    plt.show()


images, labels = next(iter(train_loader))
print(labels)
def display_batch(dataloader, num_images=5):
    images, labels = next(iter(dataloader))

    for i in range(min(num_images, len(images))):
        show_image_with_label(images[i], labels[i])

display_batch(train_loader, num_images=5)
# Out:
# tensor([7, 5, 0, 4, 1, 5, 0, 0, 5, 7, 5, 0, 1, 0, 0, 0, 0, 5, 5, 5, 0, 3, 0, 3,
#         5, 0, 5, 6, 3, 5, 2, 7, 1, 0, 3, 5, 0, 5, 3, 6, 2, 1, 5, 0, 4, 6, 0, 5,
#         0, 6, 1, 0, 2, 1, 0, 5, 5, 6, 1, 0, 1, 3])

# %%
class_names = [category['name'] for category in coco_data['categories']]
dataset_sizes = len(train_dataset) + len(val_dataset) + len(test_dataset)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# # Get a batch of training data
# inputs, classes = next(iter(train_loader))

# # Make a grid from batch
# out = torchvision.utils.make_grid(inputs)

# imshow(out, title=[class_names[x] for x in classes])

# %%
import time
from tempfile import TemporaryDirectory

def train_model(model, criterion, optimizer, scheduler, num_epochs=25, train_loader=None, val_loader=None):
    since = time.time()

    # Initialize lists to store loss and accuracy for plotting
    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')
        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Training phase
            model.train()  # Set model to training mode
            running_loss = 0.0
            running_corrects = 0

            # Iterate over training data
            for inputs, labels in train_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                # Backward + optimize only if in training phase
                loss.backward()
                optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            # Validation phase
            model.eval()  # Set model to evaluate mode
            val_loss = 0.0
            val_corrects = 0

            with torch.no_grad():  # No gradients needed during validation
                for inputs, labels in val_loader:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Statistics
                    val_loss += loss.item() * inputs.size(0)
                    val_corrects += torch.sum(preds == labels.data)

            # Update learning rate scheduler
            scheduler.step(val_loss)

            # Calculate losses and accuracies
            train_loss = running_loss / len(train_loader.dataset)
            train_acc = running_corrects.double() / len(train_loader.dataset)

            val_loss = val_loss / len(val_loader.dataset)
            val_acc = val_corrects.double() / len(val_loader.dataset)

            # Append the values for plotting
            train_losses.append(train_loss)
            train_accuracies.append(train_acc)
            val_losses.append(val_loss)
            val_accuracies.append(val_acc)

            # Print the results
            print(f'Train Loss: {train_loss:.4f} Train Acc: {train_acc:.4f}')
            print(f'Val Loss: {val_loss:.4f} Val Acc: {val_acc:.4f}')

            # Deep copy the model if we have a new best validation accuracy
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), best_model_params_path)

            print()

        # Load the best model weights
        model.load_state_dict(torch.load(best_model_params_path, weights_only=True))

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

    # Return losses and accuracies to plot
    return model, train_losses, train_accuracies, val_losses, val_accuracies

# %%
# Example: when plotting an image from a tensor
def imshow(tensor, title=None):
    """Display image for Tensor."""
    tensor = tensor.cpu().numpy().transpose((1, 2, 0))  # Move tensor to CPU and convert to NumPy
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    tensor = std * tensor + mean
    tensor = np.clip(tensor, 0, 1)
    plt.imshow(tensor)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# In the plotting function for loss and accuracy:
def plot_learning_curves(train_losses, train_accuracies, val_losses, val_accuracies):
    num_epochs = len(train_losses)

    plt.figure(figsize=(12, 6))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(range(num_epochs), train_losses, label='Train Loss')
    plt.plot(range(num_epochs), val_losses, label='Val Loss')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(range(num_epochs), train_accuracies, label='Train Accuracy')
    plt.plot(range(num_epochs), val_accuracies, label='Val Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
def visualize_model(model, num_images=6, val_loader=val_loader, class_names=class_names, device='cpu'):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j].item()]}')

                # Call imshow to display the image
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
## Load pre-trained IMAGENET1K_V1 reset final fully connected layer.

# %% [markdown]
# ## Train

# %% [markdown]
# ### ResNet50

# %%
# Train

# %%
model_ft = models.resnet50(pretrained=True)
num_ftrs = model_ft.fc.in_features

# Replace fc first
model_ft.fc = nn.Sequential(
    nn.Dropout(p=0.5),
    nn.Linear(num_ftrs, 256),
    nn.ReLU(),
    nn.Linear(256, 9)
)

# Freeze all parameters initially
for param in model_ft.parameters():
    param.requires_grad = False

# Unfreeze layer4 parameters
for name, param in model_ft.named_parameters():
    if "layer4" in name:
        param.requires_grad = True

# Unfreeze new fc parameters
for param in model_ft.fc.parameters():
    param.requires_grad = True

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

# Optional: Use different learning rates for backbone and fc
optimizer_ft = optim.Adam([
    {'params': model_ft.layer4.parameters(), 'lr': 5e-4},
    {'params': model_ft.fc.parameters(), 'lr': 5e-4}
], weight_decay=1e-3)
# Learning rate scheduler
exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer_ft, mode='min', factor=0.5, patience=3, verbose=True)
# Out:
# The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
# Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
# The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.

# %%
### Train the model
model_ft, train_loss, train_acc, val_loss, val_acc = train_model(
    model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100, train_loader=train_loader, val_loader=val_loader
)
# Out:
# Epoch 0/99
# ----------
# Train Loss: 1.7303 Train Acc: 0.3438
# Val Loss: 4.2317 Val Acc: 0.1476
#
# Epoch 1/99
# ----------
# Train Loss: 1.4709 Train Acc: 0.4216
# Val Loss: 2.4799 Val Acc: 0.2926
#
# Epoch 2/99
# ----------
# Train Loss: 1.3502 Train Acc: 0.5038
# Val Loss: 3.0357 Val Acc: 0.1679
#
# Epoch 3/99
# ----------
# Train Loss: 1.2900 Train Acc: 0.5330
# Val Loss: 2.5796 Val Acc: 0.2595
#
# Epoch 4/99
# ----------
# Train Loss: 1.1539 Train Acc: 0.5719
# Val Loss: 2.7331 Val Acc: 0.1807
#
# Epoch 5/99
# ----------
# Train Loss: 1.1977 Train Acc: 0.5805
# Val Loss: 2.7291 Val Acc: 0.3053
#
# Epoch 6/99
# ----------
# Train Loss: 1.0699 Train Acc: 0.6065
# Val Loss: 2.5929 Val Acc: 0.2290
#
# Epoch 7/99
# ----------
# Train Loss: 0.9671 Train Acc: 0.6714
# Val Loss: 2.6993 Val Acc: 0.2112
#
# Epoch 8/99
# ----------
# Train Loss: 0.9772 Train Acc: 0.6584
# Val Loss: 2.7476 Val Acc: 0.1756
#
# Epoch 9/99
# ----------
# Train Loss: 0.9216 Train Acc: 0.7016
# Val Loss: 2.5084 Val Acc: 0.2570
#
# Epoch 10/99
# ----------
# Train Loss: 0.8595 Train Acc: 0.6919
# Val Loss: 2.6492 Val Acc: 0.2519
#
# Epoch 11/99
# ----------
# Train Loss: 0.8578 Train Acc: 0.7114
# Val Loss: 2.4973 Val Acc: 0.2570
#
# Epoch 12/99
# ----------
# Train Loss: 0.7994 Train Acc: 0.7189
# Val Loss: 2.6733 Val Acc: 0.2468
#
# Epoch 13/99
# ----------
# Train Loss: 0.7782 Train Acc: 0.7276
# Val Loss: 2.5898 Val Acc: 0.2239
#
# Epoch 14/99
# ----------
# Train Loss: 0.7792 Train Acc: 0.7265
# Val Loss: 2.6420 Val Acc: 0.2392
#
# Epoch 15/99
# ----------
# Train Loss: 0.7064 Train Acc: 0.7697
# Val Loss: 2.5907 Val Acc: 0.2341
#
# Epoch 16/99
# ----------
# Train Loss: 0.7065 Train Acc: 0.7762
# Val Loss: 2.5844 Val Acc: 0.2417
#
# Epoch 17/99
# ----------
# Train Loss: 0.6733 Train Acc: 0.7870
# Val Loss: 2.6204 Val Acc: 0.2468
#
# Epoch 18/99
# ----------
# Train Loss: 0.6860 Train Acc: 0.7611
# Val Loss: 2.6396 Val Acc: 0.2494
#
# Epoch 19/99
# ----------
# Train Loss: 0.6608 Train Acc: 0.7751
# Val Loss: 2.6105 Val Acc: 0.2774
#
# Epoch 20/99
# ----------
# Train Loss: 0.6636 Train Acc: 0.7827
# Val Loss: 2.6090 Val Acc: 0.2697
#
# Epoch 21/99
# ----------
# Train Loss: 0.6347 Train Acc: 0.7957
# Val Loss: 2.6162 Val Acc: 0.2621
#
# Epoch 22/99
# ----------
# Train Loss: 0.6356 Train Acc: 0.8022
# Val Loss: 2.6193 Val Acc: 0.2646
#
# Epoch 23/99
# ----------
# Train Loss: 0.5703 Train Acc: 0.8119
# Val Loss: 2.5761 Val Acc: 0.2723
#
# Epoch 24/99
# ----------
# Train Loss: 0.5940 Train Acc: 0.8162
# Val Loss: 2.5952 Val Acc: 0.2545
#
# Epoch 25/99
# ----------
# Train Loss: 0.6111 Train Acc: 0.8022
# Val Loss: 2.6358 Val Acc: 0.2570
#
# Epoch 26/99
# ----------
# Train Loss: 0.6059 Train Acc: 0.8032
# Val Loss: 2.6584 Val Acc: 0.2443
#
# Epoch 27/99
# ----------
# Train Loss: 0.6213 Train Acc: 0.7827
# Val Loss: 2.6297 Val Acc: 0.2646
#
# Epoch 28/99
# ----------
# Train Loss: 0.6055 Train Acc: 0.7978
# Val Loss: 2.6439 Val Acc: 0.2697
#
# Epoch 29/99
# ----------
# Train Loss: 0.5920 Train Acc: 0.8108
# Val Loss: 2.6355 Val Acc: 0.2697
#
# Epoch 30/99
# ----------
# Train Loss: 0.6099 Train Acc: 0.7989
# Val Loss: 2.6612 Val Acc: 0.2748
#
# Epoch 31/99
# ----------
# Train Loss: 0.5964 Train Acc: 0.8205
# Val Loss: 2.6623 Val Acc: 0.2774
#
# Epoch 32/99
# ----------
# Train Loss: 0.5704 Train Acc: 0.8249
# Val Loss: 2.6783 Val Acc: 0.2646
#
# Epoch 33/99
# ----------
# Train Loss: 0.6046 Train Acc: 0.8097
# Val Loss: 2.7138 Val Acc: 0.2748
#
# Epoch 34/99
# ----------
# Train Loss: 0.6356 Train Acc: 0.7892
# Val Loss: 2.6924 Val Acc: 0.2646
#
# Epoch 35/99
# ----------
# Train Loss: 0.5621 Train Acc: 0.8346
# Val Loss: 2.6796 Val Acc: 0.2646
#
# Epoch 36/99
# ----------
# Train Loss: 0.5934 Train Acc: 0.7914
# Val Loss: 2.6846 Val Acc: 0.2723
#
# Epoch 37/99
# ----------
# Train Loss: 0.6107 Train Acc: 0.7957
# Val Loss: 2.6707 Val Acc: 0.2748
#
# Epoch 38/99
# ----------
# Train Loss: 0.5783 Train Acc: 0.8184
# Val Loss: 2.6557 Val Acc: 0.2697
#
# Epoch 39/99
# ----------
# Train Loss: 0.6219 Train Acc: 0.8065
# Val Loss: 2.6539 Val Acc: 0.2570
#
# Epoch 40/99
# ----------
# Train Loss: 0.5875 Train Acc: 0.8303
# Val Loss: 2.6379 Val Acc: 0.2697
#
# Epoch 41/99
# ----------
# Train Loss: 0.5989 Train Acc: 0.8086
# Val Loss: 2.6762 Val Acc: 0.2595
#
# Epoch 42/99
# ----------
# Train Loss: 0.5669 Train Acc: 0.8292
# Val Loss: 2.6760 Val Acc: 0.2672
#
# Epoch 43/99
# ----------
# Train Loss: 0.5713 Train Acc: 0.8162
# Val Loss: 2.6426 Val Acc: 0.2443
#
# Epoch 44/99
# ----------
# Train Loss: 0.5582 Train Acc: 0.8195
# Val Loss: 2.6855 Val Acc: 0.2595
#
# Epoch 45/99
# ----------
# Train Loss: 0.5705 Train Acc: 0.8292
# Val Loss: 2.6586 Val Acc: 0.2646
#
# Epoch 46/99
# ----------
# Train Loss: 0.5958 Train Acc: 0.7968
# Val Loss: 2.6710 Val Acc: 0.2621
#
# Epoch 47/99
# ----------
# Train Loss: 0.5529 Train Acc: 0.8216
# Val Loss: 2.6584 Val Acc: 0.2697
#
# Epoch 48/99
# ----------
# Train Loss: 0.6007 Train Acc: 0.8022
# Val Loss: 2.6614 Val Acc: 0.2672
#
# Epoch 49/99
# ----------
# Train Loss: 0.5869 Train Acc: 0.8173
# Val Loss: 2.6722 Val Acc: 0.2697
#
# Epoch 50/99
# ----------
# Train Loss: 0.5994 Train Acc: 0.8119
# Val Loss: 2.6798 Val Acc: 0.2646
#
# Epoch 51/99
# ----------
# Train Loss: 0.5735 Train Acc: 0.8184
# Val Loss: 2.6813 Val Acc: 0.2646
#
# Epoch 52/99
# ----------
# Train Loss: 0.6000 Train Acc: 0.7935
# Val Loss: 2.6730 Val Acc: 0.2646
#
# Epoch 53/99
# ----------
# Train Loss: 0.6270 Train Acc: 0.7859
# Val Loss: 2.6784 Val Acc: 0.2646
#
# Epoch 54/99
# ----------
# Train Loss: 0.5957 Train Acc: 0.8011
# Val Loss: 2.6739 Val Acc: 0.2570
#
# Epoch 55/99
# ----------
# Train Loss: 0.5984 Train Acc: 0.8141
# Val Loss: 2.7012 Val Acc: 0.2723
#
# Epoch 56/99
# ----------
# Train Loss: 0.5898 Train Acc: 0.8173
# Val Loss: 2.6782 Val Acc: 0.2468
#
# Epoch 57/99
# ----------
# Train Loss: 0.6027 Train Acc: 0.8076
# Val Loss: 2.6510 Val Acc: 0.2570
#
# Epoch 58/99
# ----------
# Train Loss: 0.6125 Train Acc: 0.8022
# Val Loss: 2.6638 Val Acc: 0.2697
#
# Epoch 59/99
# ----------
# Train Loss: 0.5833 Train Acc: 0.8216
# Val Loss: 2.6714 Val Acc: 0.2545
#
# Epoch 60/99
# ----------
# Train Loss: 0.5863 Train Acc: 0.8054
# Val Loss: 2.6471 Val Acc: 0.2672
#
# Epoch 61/99
# ----------
# Train Loss: 0.5695 Train Acc: 0.8130
# Val Loss: 2.6636 Val Acc: 0.2621
#
# Epoch 62/99
# ----------
# Train Loss: 0.5931 Train Acc: 0.8119
# Val Loss: 2.6930 Val Acc: 0.2621
#
# Epoch 63/99
# ----------
# Train Loss: 0.5668 Train Acc: 0.8389
# Val Loss: 2.6554 Val Acc: 0.2646
#
# Epoch 64/99
# ----------
# Train Loss: 0.6078 Train Acc: 0.8086
# Val Loss: 2.6944 Val Acc: 0.2621
#
# Epoch 65/99
# ----------
# Train Loss: 0.5807 Train Acc: 0.8205
# Val Loss: 2.6791 Val Acc: 0.2646
#
# Epoch 66/99
# ----------
# Train Loss: 0.5893 Train Acc: 0.7957
# Val Loss: 2.6804 Val Acc: 0.2723
#
# Epoch 67/99
# ----------
# Train Loss: 0.5671 Train Acc: 0.8097
# Val Loss: 2.6853 Val Acc: 0.2697
#
# Epoch 68/99
# ----------
# Train Loss: 0.5853 Train Acc: 0.8141
# Val Loss: 2.6871 Val Acc: 0.2646
#
# Epoch 69/99
# ----------
# Train Loss: 0.6011 Train Acc: 0.8043
# Val Loss: 2.6636 Val Acc: 0.2646
#
# Epoch 70/99
# ----------
# Train Loss: 0.5915 Train Acc: 0.8097
# Val Loss: 2.6574 Val Acc: 0.2799
#
# Epoch 71/99
# ----------
# Train Loss: 0.6192 Train Acc: 0.8076
# Val Loss: 2.6933 Val Acc: 0.2494
#
# Epoch 72/99
# ----------
# Train Loss: 0.5837 Train Acc: 0.8184
# Val Loss: 2.6632 Val Acc: 0.2621
#
# Epoch 73/99
# ----------
# Train Loss: 0.6179 Train Acc: 0.7978
# Val Loss: 2.6489 Val Acc: 0.2697
#
# Epoch 74/99
# ----------
# Train Loss: 0.5811 Train Acc: 0.8130
# Val Loss: 2.6886 Val Acc: 0.2723
#
# Epoch 75/99
# ----------
# Train Loss: 0.6115 Train Acc: 0.8108
# Val Loss: 2.7184 Val Acc: 0.2621
#
# Epoch 76/99
# ----------
# Train Loss: 0.5725 Train Acc: 0.8173
# Val Loss: 2.6971 Val Acc: 0.2519
#
# Epoch 77/99
# ----------
# Train Loss: 0.5802 Train Acc: 0.8032
# Val Loss: 2.6790 Val Acc: 0.2621
#
# Epoch 78/99
# ----------
# Train Loss: 0.5715 Train Acc: 0.8238
# Val Loss: 2.6633 Val Acc: 0.2595
#
# Epoch 79/99
# ----------
# Train Loss: 0.5687 Train Acc: 0.8097
# Val Loss: 2.6213 Val Acc: 0.2621
#
# Epoch 80/99
# ----------
# Train Loss: 0.5639 Train Acc: 0.8076
# Val Loss: 2.6467 Val Acc: 0.2646
#
# Epoch 81/99
# ----------
# Train Loss: 0.6226 Train Acc: 0.7957
# Val Loss: 2.7013 Val Acc: 0.2519
#
# Epoch 82/99
# ----------
# Train Loss: 0.5681 Train Acc: 0.8238
# Val Loss: 2.6902 Val Acc: 0.2646
#
# Epoch 83/99
# ----------
# Train Loss: 0.5734 Train Acc: 0.8259
# Val Loss: 2.6667 Val Acc: 0.2545
#
# Epoch 84/99
# ----------
# Train Loss: 0.5717 Train Acc: 0.8281
# Val Loss: 2.6910 Val Acc: 0.2570
#
# Epoch 85/99
# ----------
# Train Loss: 0.6249 Train Acc: 0.8076
# Val Loss: 2.7139 Val Acc: 0.2519
#
# Epoch 86/99
# ----------
# Train Loss: 0.5857 Train Acc: 0.8141
# Val Loss: 2.6568 Val Acc: 0.2570
#
# Epoch 87/99
# ----------
# Train Loss: 0.5576 Train Acc: 0.8184
# Val Loss: 2.6691 Val Acc: 0.2621
#
# Epoch 88/99
# ----------
# Train Loss: 0.5667 Train Acc: 0.8205
# Val Loss: 2.6668 Val Acc: 0.2723
#
# Epoch 89/99
# ----------
# Train Loss: 0.5738 Train Acc: 0.8205
# Val Loss: 2.6435 Val Acc: 0.2850
#
# Epoch 90/99
# ----------
# Train Loss: 0.5879 Train Acc: 0.8195
# Val Loss: 2.6808 Val Acc: 0.2672
#
# Epoch 91/99
# ----------
# Train Loss: 0.6190 Train Acc: 0.8032
# Val Loss: 2.6710 Val Acc: 0.2697
#
# Epoch 92/99
# ----------
# Train Loss: 0.5563 Train Acc: 0.8335
# Val Loss: 2.6940 Val Acc: 0.2646
#
# Epoch 93/99
# ----------
# Train Loss: 0.5531 Train Acc: 0.8249
# Val Loss: 2.6413 Val Acc: 0.2621
#
# Epoch 94/99
# ----------
# Train Loss: 0.5961 Train Acc: 0.8065
# Val Loss: 2.6885 Val Acc: 0.2723
#
# Epoch 95/99
# ----------
# Train Loss: 0.5733 Train Acc: 0.8130
# Val Loss: 2.6610 Val Acc: 0.2697
#
# Epoch 96/99
# ----------
# Train Loss: 0.6273 Train Acc: 0.7870
# Val Loss: 2.7100 Val Acc: 0.2646
#
# Epoch 97/99
# ----------
# Train Loss: 0.5833 Train Acc: 0.8086
# Val Loss: 2.6708 Val Acc: 0.2748
#
# Epoch 98/99
# ----------
# Train Loss: 0.5585 Train Acc: 0.8281
# Val Loss: 2.6521 Val Acc: 0.2646
#
# Epoch 99/99
# ----------
# Train Loss: 0.5585 Train Acc: 0.8227
# Val Loss: 2.6749 Val Acc: 0.2723
#
# Training complete in 8m 54s
# Best val Acc: 0.305344

# %%
train_acc = np.array([t.cpu().numpy() for t in train_acc])
val_acc = np.array([t.cpu().numpy() for t in val_acc])

# %%
# Plot the learning curves



print(f"Mean Train Accuracy: {np.mean(train_acc)}")
print(f"Mean Val Accuracy: {np.mean(val_acc)}")
print(f"Mean Train Loss: {np.mean(train_loss)}")
print(f"Mean Val Loss: {np.mean(val_loss)}")


plot_learning_curves(train_loss, train_acc, val_loss, val_acc)
# Out:
# Mean Train Accuracy: 0.7791999999999999
# Mean Val Accuracy: 0.25854961832061074
# Mean Train Loss: 0.6689204755183812
# Mean Val Loss: 2.677680398095352

# %%
model_ft = models.resnet50(pretrained=True)
num_ftrs = model_ft.fc.in_features

# Replace fc first
model_ft.fc = nn.Sequential(
    nn.Dropout(p=0.5),
    nn.Linear(num_ftrs, 256),
    nn.ReLU(),
    nn.Linear(256, 9)
)

# Freeze all parameters initially
for param in model_ft.parameters():
    param.requires_grad = False

# Unfreeze layer4 parameters
for name, param in model_ft.named_parameters():
    if "layer4" in name:
        param.requires_grad = True

# Unfreeze new fc parameters
for param in model_ft.fc.parameters():
    param.requires_grad = True

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

# Optional: Use different learning rates for backbone and fc
optimizer_ft = optim.Adam([
    {'params': model_ft.layer4.parameters(), 'lr': 5e-4},
    {'params': model_ft.fc.parameters(), 'lr': 5e-4}
], weight_decay=1e-3)
# Learning rate scheduler
exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer_ft, mode='min', factor=0.5, patience=3, verbose=True)
# Out:
# The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
# Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
# The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.

# %%
### Train the model
model_ft, train_loss, train_acc, val_loss, val_acc = train_model(
    model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100, train_loader=train_loader, val_loader=val_loader
)
# Out:
# Epoch 0/99
# ----------
# Train Loss: 1.7840 Train Acc: 0.3427
# Val Loss: 2.3161 Val Acc: 0.2265
#
# Epoch 1/99
# ----------
# Train Loss: 1.6730 Train Acc: 0.3751
# Val Loss: 2.8627 Val Acc: 0.1883
#
# Epoch 2/99
# ----------
# Train Loss: 1.5349 Train Acc: 0.4508
# Val Loss: 2.7178 Val Acc: 0.2214
#
# Epoch 3/99
# ----------
# Train Loss: 1.4993 Train Acc: 0.4357
# Val Loss: 2.5135 Val Acc: 0.2366
#
# Epoch 4/99
# ----------
# Train Loss: 1.4373 Train Acc: 0.4778
# Val Loss: 2.6442 Val Acc: 0.2316
#
# Epoch 5/99
# ----------
# Train Loss: 1.3709 Train Acc: 0.5254
# Val Loss: 2.5498 Val Acc: 0.2824
#
# Epoch 6/99
# ----------
# Train Loss: 1.2990 Train Acc: 0.5459
# Val Loss: 2.5373 Val Acc: 0.2875
#
# Epoch 7/99
# ----------
# Train Loss: 1.2173 Train Acc: 0.5708
# Val Loss: 2.6958 Val Acc: 0.2723
#
# Epoch 8/99
# ----------
# Train Loss: 1.1333 Train Acc: 0.6065
# Val Loss: 2.8894 Val Acc: 0.3003
#
# Epoch 9/99
# ----------
# Train Loss: 1.0205 Train Acc: 0.6541
# Val Loss: 2.5893 Val Acc: 0.2850
#
# Epoch 10/99
# ----------
# Train Loss: 0.9592 Train Acc: 0.6886
# Val Loss: 2.7218 Val Acc: 0.2977
#
# Epoch 11/99
# ----------
# Train Loss: 0.9060 Train Acc: 0.6951
# Val Loss: 2.8879 Val Acc: 0.2392
#
# Epoch 12/99
# ----------
# Train Loss: 0.8910 Train Acc: 0.7135
# Val Loss: 2.9033 Val Acc: 0.2265
#
# Epoch 13/99
# ----------
# Train Loss: 0.8270 Train Acc: 0.7395
# Val Loss: 2.8471 Val Acc: 0.2799
#
# Epoch 14/99
# ----------
# Train Loss: 0.7970 Train Acc: 0.7492
# Val Loss: 2.7933 Val Acc: 0.2417
#
# Epoch 15/99
# ----------
# Train Loss: 0.7372 Train Acc: 0.7827
# Val Loss: 2.9092 Val Acc: 0.2545
#
# Epoch 16/99
# ----------
# Train Loss: 0.7772 Train Acc: 0.7654
# Val Loss: 2.9395 Val Acc: 0.2545
#
# Epoch 17/99
# ----------
# Train Loss: 0.7095 Train Acc: 0.7903
# Val Loss: 2.9132 Val Acc: 0.2672
#
# Epoch 18/99
# ----------
# Train Loss: 0.7429 Train Acc: 0.7805
# Val Loss: 2.9929 Val Acc: 0.2697
#
# Epoch 19/99
# ----------
# Train Loss: 0.6785 Train Acc: 0.8097
# Val Loss: 2.9812 Val Acc: 0.2646
#
# Epoch 20/99
# ----------
# Train Loss: 0.6380 Train Acc: 0.8238
# Val Loss: 2.9308 Val Acc: 0.2468
#
# Epoch 21/99
# ----------
# Train Loss: 0.6366 Train Acc: 0.8184
# Val Loss: 2.9209 Val Acc: 0.2621
#
# Epoch 22/99
# ----------
# Train Loss: 0.6638 Train Acc: 0.8097
# Val Loss: 2.9745 Val Acc: 0.2545
#
# Epoch 23/99
# ----------
# Train Loss: 0.6347 Train Acc: 0.8216
# Val Loss: 2.9920 Val Acc: 0.2417
#
# Epoch 24/99
# ----------
# Train Loss: 0.6875 Train Acc: 0.7989
# Val Loss: 3.0254 Val Acc: 0.2468
#
# Epoch 25/99
# ----------
# Train Loss: 0.6493 Train Acc: 0.8173
# Val Loss: 3.0269 Val Acc: 0.2443
#
# Epoch 26/99
# ----------
# Train Loss: 0.6026 Train Acc: 0.8476
# Val Loss: 2.9953 Val Acc: 0.2545
#
# Epoch 27/99
# ----------
# Train Loss: 0.6607 Train Acc: 0.8097
# Val Loss: 3.0303 Val Acc: 0.2468
#
# Epoch 28/99
# ----------
# Train Loss: 0.6069 Train Acc: 0.8292
# Val Loss: 2.9849 Val Acc: 0.2519
#
# Epoch 29/99
# ----------
# Train Loss: 0.6341 Train Acc: 0.8108
# Val Loss: 3.0115 Val Acc: 0.2545
#
# Epoch 30/99
# ----------
# Train Loss: 0.6379 Train Acc: 0.8238
# Val Loss: 3.0064 Val Acc: 0.2545
#
# Epoch 31/99
# ----------
# Train Loss: 0.6202 Train Acc: 0.8216
# Val Loss: 3.0112 Val Acc: 0.2519
#
# Epoch 32/99
# ----------
# Train Loss: 0.6293 Train Acc: 0.8259
# Val Loss: 3.0378 Val Acc: 0.2494
#
# Epoch 33/99
# ----------
# Train Loss: 0.5919 Train Acc: 0.8335
# Val Loss: 3.0055 Val Acc: 0.2494
#
# Epoch 34/99
# ----------
# Train Loss: 0.6199 Train Acc: 0.8249
# Val Loss: 2.9905 Val Acc: 0.2443
#
# Epoch 35/99
# ----------
# Train Loss: 0.5762 Train Acc: 0.8465
# Val Loss: 2.9826 Val Acc: 0.2443
#
# Epoch 36/99
# ----------
# Train Loss: 0.5752 Train Acc: 0.8486
# Val Loss: 3.0051 Val Acc: 0.2519
#
# Epoch 37/99
# ----------
# Train Loss: 0.6334 Train Acc: 0.8238
# Val Loss: 3.0113 Val Acc: 0.2392
#
# Epoch 38/99
# ----------
# Train Loss: 0.6136 Train Acc: 0.8378
# Val Loss: 3.0207 Val Acc: 0.2443
#
# Epoch 39/99
# ----------
# Train Loss: 0.6287 Train Acc: 0.8314
# Val Loss: 2.9680 Val Acc: 0.2545
#
# Epoch 40/99
# ----------
# Train Loss: 0.6301 Train Acc: 0.8259
# Val Loss: 3.0198 Val Acc: 0.2443
#
# Epoch 41/99
# ----------
# Train Loss: 0.5831 Train Acc: 0.8508
# Val Loss: 2.9999 Val Acc: 0.2468
#
# Epoch 42/99
# ----------
# Train Loss: 0.5983 Train Acc: 0.8465
# Val Loss: 3.0008 Val Acc: 0.2494
#
# Epoch 43/99
# ----------
# Train Loss: 0.6273 Train Acc: 0.8303
# Val Loss: 3.0063 Val Acc: 0.2570
#
# Epoch 44/99
# ----------
# Train Loss: 0.6337 Train Acc: 0.8216
# Val Loss: 2.9889 Val Acc: 0.2519
#
# Epoch 45/99
# ----------
# Train Loss: 0.6566 Train Acc: 0.8130
# Val Loss: 3.0277 Val Acc: 0.2468
#
# Epoch 46/99
# ----------
# Train Loss: 0.5824 Train Acc: 0.8465
# Val Loss: 2.9903 Val Acc: 0.2443
#
# Epoch 47/99
# ----------
# Train Loss: 0.6092 Train Acc: 0.8411
# Val Loss: 3.0083 Val Acc: 0.2494
#
# Epoch 48/99
# ----------
# Train Loss: 0.6362 Train Acc: 0.8162
# Val Loss: 3.0231 Val Acc: 0.2570
#
# Epoch 49/99
# ----------
# Train Loss: 0.6170 Train Acc: 0.8314
# Val Loss: 2.9832 Val Acc: 0.2519
#
# Epoch 50/99
# ----------
# Train Loss: 0.6212 Train Acc: 0.8249
# Val Loss: 3.0039 Val Acc: 0.2341
#
# Epoch 51/99
# ----------
# Train Loss: 0.6129 Train Acc: 0.8346
# Val Loss: 3.0006 Val Acc: 0.2468
#
# Epoch 52/99
# ----------
# Train Loss: 0.5972 Train Acc: 0.8411
# Val Loss: 2.9930 Val Acc: 0.2468
#
# Epoch 53/99
# ----------
# Train Loss: 0.5905 Train Acc: 0.8465
# Val Loss: 3.0192 Val Acc: 0.2443
#
# Epoch 54/99
# ----------
# Train Loss: 0.6236 Train Acc: 0.8227
# Val Loss: 3.0055 Val Acc: 0.2468
#
# Epoch 55/99
# ----------
# Train Loss: 0.6357 Train Acc: 0.8173
# Val Loss: 2.9871 Val Acc: 0.2417
#
# Epoch 56/99
# ----------
# Train Loss: 0.6229 Train Acc: 0.8378
# Val Loss: 2.9901 Val Acc: 0.2468
#
# Epoch 57/99
# ----------
# Train Loss: 0.5866 Train Acc: 0.8422
# Val Loss: 3.0092 Val Acc: 0.2468
#
# Epoch 58/99
# ----------
# Train Loss: 0.6107 Train Acc: 0.8281
# Val Loss: 2.9924 Val Acc: 0.2494
#
# Epoch 59/99
# ----------
# Train Loss: 0.6045 Train Acc: 0.8454
# Val Loss: 3.0088 Val Acc: 0.2570
#
# Epoch 60/99
# ----------
# Train Loss: 0.6179 Train Acc: 0.8335
# Val Loss: 2.9925 Val Acc: 0.2417
#
# Epoch 61/99
# ----------
# Train Loss: 0.6402 Train Acc: 0.8151
# Val Loss: 3.0240 Val Acc: 0.2443
#
# Epoch 62/99
# ----------
# Train Loss: 0.6015 Train Acc: 0.8422
# Val Loss: 3.0259 Val Acc: 0.2443
#
# Epoch 63/99
# ----------
# Train Loss: 0.6144 Train Acc: 0.8346
# Val Loss: 3.0091 Val Acc: 0.2545
#
# Epoch 64/99
# ----------
# Train Loss: 0.6033 Train Acc: 0.8378
# Val Loss: 2.9667 Val Acc: 0.2519
#
# Epoch 65/99
# ----------
# Train Loss: 0.5980 Train Acc: 0.8432
# Val Loss: 2.9955 Val Acc: 0.2443
#
# Epoch 66/99
# ----------
# Train Loss: 0.6234 Train Acc: 0.8259
# Val Loss: 3.0086 Val Acc: 0.2443
#
# Epoch 67/99
# ----------
# Train Loss: 0.6139 Train Acc: 0.8259
# Val Loss: 3.0170 Val Acc: 0.2468
#
# Epoch 68/99
# ----------
# Train Loss: 0.6010 Train Acc: 0.8411
# Val Loss: 3.0346 Val Acc: 0.2316
#
# Epoch 69/99
# ----------
# Train Loss: 0.6207 Train Acc: 0.8270
# Val Loss: 3.0135 Val Acc: 0.2392
#
# Epoch 70/99
# ----------
# Train Loss: 0.6080 Train Acc: 0.8314
# Val Loss: 3.0248 Val Acc: 0.2468
#
# Epoch 71/99
# ----------
# Train Loss: 0.6048 Train Acc: 0.8411
# Val Loss: 2.9869 Val Acc: 0.2468
#
# Epoch 72/99
# ----------
# Train Loss: 0.6445 Train Acc: 0.8227
# Val Loss: 3.0025 Val Acc: 0.2366
#
# Epoch 73/99
# ----------
# Train Loss: 0.6126 Train Acc: 0.8422
# Val Loss: 2.9981 Val Acc: 0.2443
#
# Epoch 74/99
# ----------
# Train Loss: 0.6326 Train Acc: 0.8259
# Val Loss: 3.0100 Val Acc: 0.2494
#
# Epoch 75/99
# ----------
# Train Loss: 0.5949 Train Acc: 0.8400
# Val Loss: 2.9945 Val Acc: 0.2519
#
# Epoch 76/99
# ----------
# Train Loss: 0.6043 Train Acc: 0.8216
# Val Loss: 2.9861 Val Acc: 0.2494
#
# Epoch 77/99
# ----------
# Train Loss: 0.5861 Train Acc: 0.8486
# Val Loss: 3.0049 Val Acc: 0.2443
#
# Epoch 78/99
# ----------
# Train Loss: 0.6074 Train Acc: 0.8368
# Val Loss: 3.0143 Val Acc: 0.2570
#
# Epoch 79/99
# ----------
# Train Loss: 0.6102 Train Acc: 0.8389
# Val Loss: 3.0092 Val Acc: 0.2392
#
# Epoch 80/99
# ----------
# Train Loss: 0.6135 Train Acc: 0.8292
# Val Loss: 2.9984 Val Acc: 0.2545
#
# Epoch 81/99
# ----------
# Train Loss: 0.6004 Train Acc: 0.8411
# Val Loss: 2.9637 Val Acc: 0.2443
#
# Epoch 82/99
# ----------
# Train Loss: 0.5917 Train Acc: 0.8422
# Val Loss: 2.9766 Val Acc: 0.2468
#
# Epoch 83/99
# ----------
# Train Loss: 0.5863 Train Acc: 0.8519
# Val Loss: 2.9912 Val Acc: 0.2519
#
# Epoch 84/99
# ----------
# Train Loss: 0.6213 Train Acc: 0.8216
# Val Loss: 3.0207 Val Acc: 0.2443
#
# Epoch 85/99
# ----------
# Train Loss: 0.6268 Train Acc: 0.8238
# Val Loss: 3.0475 Val Acc: 0.2417
#
# Epoch 86/99
# ----------
# Train Loss: 0.6370 Train Acc: 0.8184
# Val Loss: 3.0371 Val Acc: 0.2366
#
# Epoch 87/99
# ----------
# Train Loss: 0.5773 Train Acc: 0.8541
# Val Loss: 2.9905 Val Acc: 0.2443
#
# Epoch 88/99
# ----------
# Train Loss: 0.6172 Train Acc: 0.8281
# Val Loss: 2.9984 Val Acc: 0.2494
#
# Epoch 89/99
# ----------
# Train Loss: 0.6465 Train Acc: 0.8173
# Val Loss: 2.9944 Val Acc: 0.2468
#
# Epoch 90/99
# ----------
# Train Loss: 0.6019 Train Acc: 0.8346
# Val Loss: 2.9851 Val Acc: 0.2494
#
# Epoch 91/99
# ----------
# Train Loss: 0.6278 Train Acc: 0.8270
# Val Loss: 2.9921 Val Acc: 0.2545
#
# Epoch 92/99
# ----------
# Train Loss: 0.6482 Train Acc: 0.8119
# Val Loss: 3.0345 Val Acc: 0.2468
#
# Epoch 93/99
# ----------
# Train Loss: 0.6273 Train Acc: 0.8249
# Val Loss: 2.9894 Val Acc: 0.2417
#
# Epoch 94/99
# ----------
# Train Loss: 0.6251 Train Acc: 0.8249
# Val Loss: 3.0005 Val Acc: 0.2494
#
# Epoch 95/99
# ----------
# Train Loss: 0.5909 Train Acc: 0.8519
# Val Loss: 3.0035 Val Acc: 0.2417
#
# Epoch 96/99
# ----------
# Train Loss: 0.6293 Train Acc: 0.8227
# Val Loss: 3.0440 Val Acc: 0.2494
#
# Epoch 97/99
# ----------
# Train Loss: 0.6046 Train Acc: 0.8259
# Val Loss: 3.0068 Val Acc: 0.2545
#
# Epoch 98/99
# ----------
# Train Loss: 0.5907 Train Acc: 0.8422
# Val Loss: 3.0091 Val Acc: 0.2494
#
# Epoch 99/99
# ----------
# Train Loss: 0.5967 Train Acc: 0.8378
# Val Loss: 3.0171 Val Acc: 0.2468
#
# Training complete in 9m 14s
# Best val Acc: 0.300254

# %%
train_acc = np.array([t.cpu().numpy() for t in train_acc])
val_acc = np.array([t.cpu().numpy() for t in val_acc])

# %%
# Plot the learning curves



print(f"Mean Train Accuracy: {np.mean(train_acc)}")
print(f"Mean Val Accuracy: {np.mean(val_acc)}")
print(f"Mean Train Loss: {np.mean(train_loss)}")
print(f"Mean Val Loss: {np.mean(val_loss)}")


plot_learning_curves(train_loss, train_acc, val_loss, val_acc)
# Out:
# Mean Train Accuracy: 0.7897513513513513
# Mean Val Accuracy: 0.24926208651399492
# Mean Train Loss: 0.7131513642423861
# Mean Val Loss: 2.9541482312867355

# %% [markdown]
# ### ResNet18

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features

# Replace the final FC layer
model_ft.fc = nn.Sequential(
    nn.Dropout(p=0.5),
    nn.Linear(num_ftrs, 128),
    nn.ReLU(),
    nn.Linear(128, 9)
)

# Freeze all pretrained layers
for param in model_ft.parameters():
    param.requires_grad = False

# Unfreeze only the new FC layer
for param in model_ft.fc.parameters():
    param.requires_grad = True

for name, param in model_ft.named_parameters():
    if "layer2" in name or "layer3" in name or "layer4" in name:
        param.requires_grad = True


# Move to GPU if available
model_ft = model_ft.to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

optimizer_ft = optim.Adam([
    {'params': model_ft.fc.parameters(), 'lr': 1e-4},
    {'params': model_ft.layer4.parameters(), 'lr': 5e-5},
    {'params': model_ft.layer3.parameters(), 'lr': 2e-5},
    {'params': model_ft.layer2.parameters(), 'lr': 2e-5}
], weight_decay=1e-4)


# Learning rate scheduler
exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer_ft, mode='min', factor=0.5, patience=3, verbose=True)
# Out:
# Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.

# %%
### Train the model
model_ft, train_loss, train_acc, val_loss, val_acc = train_model(
    model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100, train_loader=train_loader, val_loader=val_loader
)
# Out:
# Epoch 0/99
# ----------
# Train Loss: 2.0880 Train Acc: 0.1632
# Val Loss: 2.0375 Val Acc: 0.2697
#
# Epoch 1/99
# ----------
# Train Loss: 1.8489 Train Acc: 0.3373
# Val Loss: 1.9958 Val Acc: 0.3232
#
# Epoch 2/99
# ----------
# Train Loss: 1.7779 Train Acc: 0.3622
# Val Loss: 2.0383 Val Acc: 0.3232
#
# Epoch 3/99
# ----------
# Train Loss: 1.7492 Train Acc: 0.3654
# Val Loss: 2.0485 Val Acc: 0.3206
#
# Epoch 4/99
# ----------
# Train Loss: 1.7136 Train Acc: 0.3676
# Val Loss: 2.0595 Val Acc: 0.3155
#
# Epoch 5/99
# ----------
# Train Loss: 1.6811 Train Acc: 0.3741
# Val Loss: 2.0717 Val Acc: 0.3155
#
# Epoch 6/99
# ----------
# Train Loss: 1.6616 Train Acc: 0.3730
# Val Loss: 2.0782 Val Acc: 0.2901
#
# Epoch 7/99
# ----------
# Train Loss: 1.6409 Train Acc: 0.3762
# Val Loss: 2.0957 Val Acc: 0.2646
#
# Epoch 8/99
# ----------
# Train Loss: 1.6297 Train Acc: 0.3838
# Val Loss: 2.1102 Val Acc: 0.2748
#
# Epoch 9/99
# ----------
# Train Loss: 1.6212 Train Acc: 0.3816
# Val Loss: 2.1283 Val Acc: 0.2748
#
# Epoch 10/99
# ----------
# Train Loss: 1.5934 Train Acc: 0.3881
# Val Loss: 2.1242 Val Acc: 0.2697
#
# Epoch 11/99
# ----------
# Train Loss: 1.5849 Train Acc: 0.3849
# Val Loss: 2.1319 Val Acc: 0.2545
#
# Epoch 12/99
# ----------
# Train Loss: 1.5698 Train Acc: 0.4162
# Val Loss: 2.1380 Val Acc: 0.2595
#
# Epoch 13/99
# ----------
# Train Loss: 1.5686 Train Acc: 0.3903
# Val Loss: 2.1486 Val Acc: 0.2595
#
# Epoch 14/99
# ----------
# Train Loss: 1.5464 Train Acc: 0.3957
# Val Loss: 2.1508 Val Acc: 0.2494
#
# Epoch 15/99
# ----------
# Train Loss: 1.5555 Train Acc: 0.4151
# Val Loss: 2.1521 Val Acc: 0.2570
#
# Epoch 16/99
# ----------
# Train Loss: 1.5576 Train Acc: 0.4108
# Val Loss: 2.1530 Val Acc: 0.2519
#
# Epoch 17/99
# ----------
# Train Loss: 1.5697 Train Acc: 0.4065
# Val Loss: 2.1650 Val Acc: 0.2366
#
# Epoch 18/99
# ----------
# Train Loss: 1.5505 Train Acc: 0.4162
# Val Loss: 2.1589 Val Acc: 0.2494
#
# Epoch 19/99
# ----------
# Train Loss: 1.5517 Train Acc: 0.4108
# Val Loss: 2.1640 Val Acc: 0.2468
#
# Epoch 20/99
# ----------
# Train Loss: 1.5414 Train Acc: 0.4162
# Val Loss: 2.1606 Val Acc: 0.2570
#
# Epoch 21/99
# ----------
# Train Loss: 1.5464 Train Acc: 0.4173
# Val Loss: 2.1601 Val Acc: 0.2545
#
# Epoch 22/99
# ----------
# Train Loss: 1.5335 Train Acc: 0.4130
# Val Loss: 2.1652 Val Acc: 0.2519
#
# Epoch 23/99
# ----------
# Train Loss: 1.5303 Train Acc: 0.4292
# Val Loss: 2.1683 Val Acc: 0.2545
#
# Epoch 24/99
# ----------
# Train Loss: 1.5559 Train Acc: 0.4065
# Val Loss: 2.1753 Val Acc: 0.2494
#
# Epoch 25/99
# ----------
# Train Loss: 1.5561 Train Acc: 0.4119
# Val Loss: 2.1599 Val Acc: 0.2595
#
# Epoch 26/99
# ----------
# Train Loss: 1.5515 Train Acc: 0.4043
# Val Loss: 2.1554 Val Acc: 0.2595
#
# Epoch 27/99
# ----------
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^Exception ignored in: ^^<function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>^
# ^Traceback (most recent call last):
# ^  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# ^    ^self._shutdown_workers()^
# ^  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# ^^
# if w.is_alive():  File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#
#      assert self._parent_pid == os.getpid(), 'can only test a child process'
#           ^ ^ ^ ^ ^ ^ ^^^^^^^^^^^^
# ^  File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# ^^    ^assert self._parent_pid == os.getpid(), 'can only test a child process'^
# ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^^^^^^^^^^^^^^^^^
# ^AssertionError^: ^can only test a child process^
# ^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Train Loss: 1.5567 Train Acc: 0.3924
# Val Loss: 2.1609 Val Acc: 0.2519
#
# Epoch 28/99
# ----------
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80><function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
# Train Loss: 1.5373 Train Acc: 0.4259
# Val Loss: 2.1593 Val Acc: 0.2595
#
# Epoch 29/99
# ----------
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^Exception ignored in: ^^<function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>^^
# ^Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# ^^    ^self._shutdown_workers()^
# ^  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# ^    ^if w.is_alive():^
# ^ ^ ^ ^ ^ ^ ^ ^^^^
# ^AssertionError^: ^can only test a child process^
# ^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Train Loss: 1.5510 Train Acc: 0.4130
# Val Loss: 2.1597 Val Acc: 0.2545
#
# Epoch 30/99
# ----------
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Train Loss: 1.5549 Train Acc: 0.4141
# Val Loss: 2.1615 Val Acc: 0.2570
#
# Epoch 31/99
# ----------
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^Exception ignored in: ^^<function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>^
# ^Traceback (most recent call last):
# ^  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
#       File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# self._shutdown_workers()
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#       if w.is_alive():
#                ^^^^^^^^^^^^^^^^^^^^^^^^
# ^  File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# ^    ^assert self._parent_pid == os.getpid(), 'can only test a child process'^
# ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^^^^^^^^
# ^AssertionError^: ^can only test a child process^
# ^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Train Loss: 1.5492 Train Acc: 0.4227
# Val Loss: 2.1564 Val Acc: 0.2646
#
# Epoch 32/99
# ----------
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^Exception ignored in: ^^<function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>^
# ^Traceback (most recent call last):
# ^  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# ^^    ^self._shutdown_workers()^
#
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#               ^ ^ ^ ^ ^^^^^^^^^^^^^^^^
# ^  File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# ^    ^assert self._parent_pid == os.getpid(), 'can only test a child process'^
# ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^^^^^^^^^^^^^^^^
# ^AssertionError^: ^can only test a child process^
# ^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Train Loss: 1.5415 Train Acc: 0.4119
# Val Loss: 2.1604 Val Acc: 0.2621
#
# Epoch 33/99
# ----------
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# Exception ignored in:     assert self._parent_pid == os.getpid(), 'can only test a child process'<function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>
#
#  Traceback (most recent call last):
#    File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#        self._shutdown_workers()
#    File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#        if w.is_alive():
#  ^ ^ ^ ^ ^^ ^ ^ ^^^^^^^^^^^^^^^^^^^^^^^^^
# ^  File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# ^    ^assert self._parent_pid == os.getpid(), 'can only test a child process'^
# ^ ^^  ^ ^ ^
#  AssertionError :  can only test a child process
#  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Train Loss: 1.5337 Train Acc: 0.4065
# Val Loss: 2.1641 Val Acc: 0.2570
#
# Epoch 34/99
# ----------
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>Exception ignored in:
# Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7adc4dfc1a80>  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#
# Traceback (most recent call last):
#       File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
# self._shutdown_workers()
#       File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
# self._shutdown_workers()
#     if w.is_alive():  File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#
#      if w.is_alive():
#           ^ ^ ^^^^^^^^^^^^^^^^^^^^
# ^  File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# ^
#       File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#                    ^ ^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Train Loss: 1.5383 Train Acc: 0.4032
# Val Loss: 2.1580 Val Acc: 0.2570
#
# Epoch 35/99
# ----------
# Train Loss: 1.5300 Train Acc: 0.4292
# Val Loss: 2.1513 Val Acc: 0.2646
#
# Epoch 36/99
# ----------
# Train Loss: 1.5461 Train Acc: 0.4097
# Val Loss: 2.1652 Val Acc: 0.2621
#
# Epoch 37/99
# ----------
# Train Loss: 1.5456 Train Acc: 0.4119
# Val Loss: 2.1569 Val Acc: 0.2646
#
# Epoch 38/99
# ----------
# Train Loss: 1.5301 Train Acc: 0.4173
# Val Loss: 2.1608 Val Acc: 0.2545
#
# Epoch 39/99
# ----------
# Train Loss: 1.5333 Train Acc: 0.4108
# Val Loss: 2.1665 Val Acc: 0.2494
#
# Epoch 40/99
# ----------
# Train Loss: 1.5321 Train Acc: 0.4151
# Val Loss: 2.1651 Val Acc: 0.2519
#
# Epoch 41/99
# ----------
# Train Loss: 1.5415 Train Acc: 0.4151
# Val Loss: 2.1605 Val Acc: 0.2570
#
# Epoch 42/99
# ----------
# Train Loss: 1.5410 Train Acc: 0.4173
# Val Loss: 2.1631 Val Acc: 0.2545
#
# Epoch 43/99
# ----------
# Train Loss: 1.5412 Train Acc: 0.4227
# Val Loss: 2.1651 Val Acc: 0.2519
#
# Epoch 44/99
# ----------
# Train Loss: 1.5595 Train Acc: 0.4097
# Val Loss: 2.1624 Val Acc: 0.2494
#
# Epoch 45/99
# ----------
# Train Loss: 1.5431 Train Acc: 0.4011
# Val Loss: 2.1705 Val Acc: 0.2443
#
# Epoch 46/99
# ----------
# Train Loss: 1.5417 Train Acc: 0.4076
# Val Loss: 2.1595 Val Acc: 0.2519
#
# Epoch 47/99
# ----------
# Train Loss: 1.5350 Train Acc: 0.4216
# Val Loss: 2.1661 Val Acc: 0.2494
#
# Epoch 48/99
# ----------
# Train Loss: 1.5500 Train Acc: 0.4000
# Val Loss: 2.1618 Val Acc: 0.2595
#
# Epoch 49/99
# ----------
# Train Loss: 1.5252 Train Acc: 0.4303
# Val Loss: 2.1618 Val Acc: 0.2545
#
# Epoch 50/99
# ----------
# Train Loss: 1.5402 Train Acc: 0.4216
# Val Loss: 2.1617 Val Acc: 0.2621
#
# Epoch 51/99
# ----------
# Train Loss: 1.5169 Train Acc: 0.4162
# Val Loss: 2.1618 Val Acc: 0.2595
#
# Epoch 52/99
# ----------
# Train Loss: 1.5397 Train Acc: 0.4151
# Val Loss: 2.1607 Val Acc: 0.2545
#
# Epoch 53/99
# ----------
# Train Loss: 1.5310 Train Acc: 0.4368
# Val Loss: 2.1625 Val Acc: 0.2519
#
# Epoch 54/99
# ----------
# Train Loss: 1.5324 Train Acc: 0.4281
# Val Loss: 2.1586 Val Acc: 0.2621
#
# Epoch 55/99
# ----------
# Train Loss: 1.5376 Train Acc: 0.3989
# Val Loss: 2.1640 Val Acc: 0.2595
#
# Epoch 56/99
# ----------
# Train Loss: 1.5391 Train Acc: 0.4076
# Val Loss: 2.1695 Val Acc: 0.2494
#
# Epoch 57/99
# ----------
# Train Loss: 1.5255 Train Acc: 0.4227
# Val Loss: 2.1583 Val Acc: 0.2595
#
# Epoch 58/99
# ----------
# Train Loss: 1.5254 Train Acc: 0.4076
# Val Loss: 2.1616 Val Acc: 0.2570
#
# Epoch 59/99
# ----------
# Train Loss: 1.5416 Train Acc: 0.4151
# Val Loss: 2.1617 Val Acc: 0.2545
#
# Epoch 60/99
# ----------
# Train Loss: 1.5239 Train Acc: 0.4173
# Val Loss: 2.1619 Val Acc: 0.2570
#
# Epoch 61/99
# ----------
# Train Loss: 1.5348 Train Acc: 0.4032
# Val Loss: 2.1667 Val Acc: 0.2468
#
# Epoch 62/99
# ----------
# Train Loss: 1.5328 Train Acc: 0.4054
# Val Loss: 2.1717 Val Acc: 0.2545
#
# Epoch 63/99
# ----------
# Train Loss: 1.5260 Train Acc: 0.4173
# Val Loss: 2.1604 Val Acc: 0.2570
#
# Epoch 64/99
# ----------
# Train Loss: 1.5223 Train Acc: 0.4227
# Val Loss: 2.1631 Val Acc: 0.2545
#
# Epoch 65/99
# ----------
# Train Loss: 1.5391 Train Acc: 0.4162
# Val Loss: 2.1609 Val Acc: 0.2545
#
# Epoch 66/99
# ----------
# Train Loss: 1.5484 Train Acc: 0.4173
# Val Loss: 2.1548 Val Acc: 0.2595
#
# Epoch 67/99
# ----------
# Train Loss: 1.5190 Train Acc: 0.4227
# Val Loss: 2.1617 Val Acc: 0.2494
#
# Epoch 68/99
# ----------
# Train Loss: 1.5402 Train Acc: 0.4151
# Val Loss: 2.1572 Val Acc: 0.2545
#
# Epoch 69/99
# ----------
# Train Loss: 1.5474 Train Acc: 0.4097
# Val Loss: 2.1589 Val Acc: 0.2468
#
# Epoch 70/99
# ----------
# Train Loss: 1.5345 Train Acc: 0.4249
# Val Loss: 2.1595 Val Acc: 0.2570
#
# Epoch 71/99
# ----------
# Train Loss: 1.5351 Train Acc: 0.4205
# Val Loss: 2.1563 Val Acc: 0.2570
#
# Epoch 72/99
# ----------
# Train Loss: 1.5332 Train Acc: 0.4195
# Val Loss: 2.1574 Val Acc: 0.2570
#
# Epoch 73/99
# ----------
# Train Loss: 1.5505 Train Acc: 0.4000
# Val Loss: 2.1664 Val Acc: 0.2494
#
# Epoch 74/99
# ----------
# Train Loss: 1.5370 Train Acc: 0.4097
# Val Loss: 2.1556 Val Acc: 0.2545
#
# Epoch 75/99
# ----------
# Train Loss: 1.5306 Train Acc: 0.4141
# Val Loss: 2.1581 Val Acc: 0.2570
#
# Epoch 76/99
# ----------
# Train Loss: 1.5202 Train Acc: 0.4335
# Val Loss: 2.1708 Val Acc: 0.2494
#
# Epoch 77/99
# ----------
# Train Loss: 1.5437 Train Acc: 0.4076
# Val Loss: 2.1655 Val Acc: 0.2545
#
# Epoch 78/99
# ----------
# Train Loss: 1.5294 Train Acc: 0.4054
# Val Loss: 2.1578 Val Acc: 0.2570
#
# Epoch 79/99
# ----------
# Train Loss: 1.5382 Train Acc: 0.4216
# Val Loss: 2.1562 Val Acc: 0.2595
#
# Epoch 80/99
# ----------
# Train Loss: 1.5570 Train Acc: 0.4043
# Val Loss: 2.1574 Val Acc: 0.2646
#
# Epoch 81/99
# ----------
# Train Loss: 1.5359 Train Acc: 0.4054
# Val Loss: 2.1544 Val Acc: 0.2595
#
# Epoch 82/99
# ----------
# Train Loss: 1.5477 Train Acc: 0.4108
# Val Loss: 2.1592 Val Acc: 0.2595
#
# Epoch 83/99
# ----------
# Train Loss: 1.5203 Train Acc: 0.4130
# Val Loss: 2.1554 Val Acc: 0.2672
#
# Epoch 84/99
# ----------
# Train Loss: 1.5295 Train Acc: 0.4162
# Val Loss: 2.1618 Val Acc: 0.2595
#
# Epoch 85/99
# ----------
# Train Loss: 1.5346 Train Acc: 0.4097
# Val Loss: 2.1588 Val Acc: 0.2570
#
# Epoch 86/99
# ----------
# Train Loss: 1.5313 Train Acc: 0.4162
# Val Loss: 2.1570 Val Acc: 0.2570
#
# Epoch 87/99
# ----------
# Train Loss: 1.5093 Train Acc: 0.4184
# Val Loss: 2.1563 Val Acc: 0.2595
#
# Epoch 88/99
# ----------
# Train Loss: 1.5332 Train Acc: 0.4162
# Val Loss: 2.1614 Val Acc: 0.2646
#
# Epoch 89/99
# ----------
# Train Loss: 1.5339 Train Acc: 0.4205
# Val Loss: 2.1686 Val Acc: 0.2570
#
# Epoch 90/99
# ----------
# Train Loss: 1.5285 Train Acc: 0.4151
# Val Loss: 2.1562 Val Acc: 0.2595
#
# Epoch 91/99
# ----------
# Train Loss: 1.5338 Train Acc: 0.4249
# Val Loss: 2.1645 Val Acc: 0.2595
#
# Epoch 92/99
# ----------
# Train Loss: 1.5382 Train Acc: 0.4043
# Val Loss: 2.1525 Val Acc: 0.2570
#
# Epoch 93/99
# ----------
# Train Loss: 1.5494 Train Acc: 0.4195
# Val Loss: 2.1582 Val Acc: 0.2570
#
# Epoch 94/99
# ----------
# Train Loss: 1.5360 Train Acc: 0.4270
# Val Loss: 2.1579 Val Acc: 0.2595
#
# Epoch 95/99
# ----------
# Train Loss: 1.5345 Train Acc: 0.4151
# Val Loss: 2.1537 Val Acc: 0.2672
#
# Epoch 96/99
# ----------
# Train Loss: 1.5365 Train Acc: 0.4227
# Val Loss: 2.1607 Val Acc: 0.2646
#
# Epoch 97/99
# ----------
# Train Loss: 1.5586 Train Acc: 0.4043
# Val Loss: 2.1649 Val Acc: 0.2621
#
# Epoch 98/99
# ----------
# Train Loss: 1.5471 Train Acc: 0.4076
# Val Loss: 2.1635 Val Acc: 0.2545
#
# Epoch 99/99
# ----------
# Train Loss: 1.5311 Train Acc: 0.4335
# Val Loss: 2.1633 Val Acc: 0.2545
#
# Training complete in 10m 7s
# Best val Acc: 0.323155

# %%
train_acc = np.array([t.cpu().numpy() for t in train_acc])
val_acc = np.array([t.cpu().numpy() for t in val_acc])

# %%
# Plot the learning curves



print(f"Mean Train Accuracy: {np.mean(train_acc)}")
print(f"Mean Val Accuracy: {np.mean(val_acc)}")
print(f"Mean Train Loss: {np.mean(train_loss)}")
print(f"Mean Val Loss: {np.mean(val_loss)}")


plot_learning_curves(train_loss, train_acc, val_loss, val_acc)
# Out:
# Mean Train Accuracy: 0.4070486486486486
# Mean Val Accuracy: 0.26033078880407123
# Mean Train Loss: 1.5607517243411093
# Mean Val Loss: 2.150392918253066

# %% [markdown]
# ## mobilenet_v2

# %%
from torchvision import models

model_ft = models.mobilenet_v2(pretrained=True)
num_ftrs = model_ft.classifier[1].in_features

# Replace classifier
model_ft.classifier = nn.Sequential(
    nn.Dropout(p=0.3),
    nn.Linear(num_ftrs, 9)  # Your number of classes
)
for param in model_ft.parameters():
    param.requires_grad = False

for param in model_ft.classifier.parameters():
    param.requires_grad = True
criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

optimizer_ft = optim.Adam([
    {'params': model_ft.classifier.parameters(), 'lr': 1e-4}
], weight_decay=1e-4)
model_ft = model_ft.to(device)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.5)

# %%
### Train the model
model_ft, train_loss, train_acc, val_loss, val_acc = train_model(
    model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100, train_loader=train_loader, val_loader=val_loader
)
# Out:
# Epoch 0/99
# ----------
# Train Loss: 2.0166 Train Acc: 0.2173
# Val Loss: 2.0182 Val Acc: 0.2519
#
# Epoch 1/99
# ----------
# The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
# Train Loss: 1.8827 Train Acc: 0.2768
# Val Loss: 2.0278 Val Acc: 0.2188
#
# Epoch 2/99
# ----------
# Train Loss: 1.8780 Train Acc: 0.2692
# Val Loss: 2.0315 Val Acc: 0.2163
#
# Epoch 3/99
# ----------
# Train Loss: 1.8585 Train Acc: 0.3049
# Val Loss: 2.0336 Val Acc: 0.2112
#
# Epoch 4/99
# ----------
# Train Loss: 1.8590 Train Acc: 0.2832
# Val Loss: 2.0303 Val Acc: 0.2239
#
# Epoch 5/99
# ----------
# Train Loss: 1.8544 Train Acc: 0.2886
# Val Loss: 2.0309 Val Acc: 0.2214
#
# Epoch 6/99
# ----------
# Train Loss: 1.8619 Train Acc: 0.3027
# Val Loss: 2.0316 Val Acc: 0.2112
#
# Epoch 7/99
# ----------
# Train Loss: 1.8513 Train Acc: 0.2984
# Val Loss: 2.0333 Val Acc: 0.2087
#
# Epoch 8/99
# ----------
# Train Loss: 1.8796 Train Acc: 0.2778
# Val Loss: 2.0281 Val Acc: 0.2163
#
# Epoch 9/99
# ----------
# Train Loss: 1.8599 Train Acc: 0.3005
# Val Loss: 2.0296 Val Acc: 0.2137
#
# Epoch 10/99
# ----------
# Train Loss: 1.8740 Train Acc: 0.2800
# Val Loss: 2.0296 Val Acc: 0.2036
#
# Epoch 11/99
# ----------
# Train Loss: 1.8750 Train Acc: 0.2822
# Val Loss: 2.0307 Val Acc: 0.2087
#
# Epoch 12/99
# ----------
# Train Loss: 1.8585 Train Acc: 0.2876
# Val Loss: 2.0278 Val Acc: 0.2087
#
# Epoch 13/99
# ----------
# Train Loss: 1.8682 Train Acc: 0.2735
# Val Loss: 2.0308 Val Acc: 0.2137
#
# Epoch 14/99
# ----------
# Train Loss: 1.8767 Train Acc: 0.2962
# Val Loss: 2.0286 Val Acc: 0.2087
#
# Epoch 15/99
# ----------
# Train Loss: 1.8688 Train Acc: 0.2822
# Val Loss: 2.0282 Val Acc: 0.2137
#
# Epoch 16/99
# ----------
# Train Loss: 1.8745 Train Acc: 0.2800
# Val Loss: 2.0319 Val Acc: 0.2061
#
# Epoch 17/99
# ----------
# Train Loss: 1.8585 Train Acc: 0.2886
# Val Loss: 2.0266 Val Acc: 0.2214
#
# Epoch 18/99
# ----------
# Train Loss: 1.8567 Train Acc: 0.2800
# Val Loss: 2.0286 Val Acc: 0.2087
#
# Epoch 19/99
# ----------
# Train Loss: 1.8653 Train Acc: 0.2822
# Val Loss: 2.0330 Val Acc: 0.2137
#
# Epoch 20/99
# ----------
# Train Loss: 1.8438 Train Acc: 0.2941
# Val Loss: 2.0293 Val Acc: 0.2112
#
# Epoch 21/99
# ----------
# Train Loss: 1.8673 Train Acc: 0.2854
# Val Loss: 2.0329 Val Acc: 0.2137
#
# Epoch 22/99
# ----------
# Train Loss: 1.8708 Train Acc: 0.2973
# Val Loss: 2.0304 Val Acc: 0.2214
#
# Epoch 23/99
# ----------
# Train Loss: 1.8616 Train Acc: 0.2789
# Val Loss: 2.0324 Val Acc: 0.2087
#
# Epoch 24/99
# ----------
# Train Loss: 1.8629 Train Acc: 0.2789
# Val Loss: 2.0315 Val Acc: 0.2087
#
# Epoch 25/99
# ----------
# Train Loss: 1.8744 Train Acc: 0.2800
# Val Loss: 2.0351 Val Acc: 0.2087
#
# Epoch 26/99
# ----------
# Train Loss: 1.8641 Train Acc: 0.3124
# Val Loss: 2.0263 Val Acc: 0.2239
#
# Epoch 27/99
# ----------
# Train Loss: 1.8501 Train Acc: 0.3038
# Val Loss: 2.0290 Val Acc: 0.2265
#
# Epoch 28/99
# ----------
# Train Loss: 1.8686 Train Acc: 0.2832
# Val Loss: 2.0253 Val Acc: 0.2188
#
# Epoch 29/99
# ----------
# Train Loss: 1.8658 Train Acc: 0.2757
# Val Loss: 2.0288 Val Acc: 0.2188
#
# Epoch 30/99
# ----------
# Train Loss: 1.8595 Train Acc: 0.2962
# Val Loss: 2.0269 Val Acc: 0.2214
#
# Epoch 31/99
# ----------
# Train Loss: 1.8773 Train Acc: 0.2659
# Val Loss: 2.0310 Val Acc: 0.2112
#
# Epoch 32/99
# ----------
# Train Loss: 1.8537 Train Acc: 0.3189
# Val Loss: 2.0323 Val Acc: 0.2036
#
# Epoch 33/99
# ----------
# Train Loss: 1.8820 Train Acc: 0.2800
# Val Loss: 2.0324 Val Acc: 0.2112
#
# Epoch 34/99
# ----------
# Train Loss: 1.8770 Train Acc: 0.2811
# Val Loss: 2.0310 Val Acc: 0.2087
#
# Epoch 35/99
# ----------
# Train Loss: 1.8670 Train Acc: 0.2757
# Val Loss: 2.0304 Val Acc: 0.2137
#
# Epoch 36/99
# ----------
# Train Loss: 1.8546 Train Acc: 0.2757
# Val Loss: 2.0319 Val Acc: 0.2087
#
# Epoch 37/99
# ----------
# Train Loss: 1.8727 Train Acc: 0.2800
# Val Loss: 2.0279 Val Acc: 0.2137
#
# Epoch 38/99
# ----------
# Train Loss: 1.8435 Train Acc: 0.3070
# Val Loss: 2.0299 Val Acc: 0.2163
#
# Epoch 39/99
# ----------
# Train Loss: 1.8629 Train Acc: 0.3038
# Val Loss: 2.0273 Val Acc: 0.2137
#
# Epoch 40/99
# ----------
# Train Loss: 1.8710 Train Acc: 0.2724
# Val Loss: 2.0263 Val Acc: 0.2188
#
# Epoch 41/99
# ----------
# Train Loss: 1.8718 Train Acc: 0.2714
# Val Loss: 2.0302 Val Acc: 0.2112
#
# Epoch 42/99
# ----------
# Train Loss: 1.8639 Train Acc: 0.2768
# Val Loss: 2.0298 Val Acc: 0.2112
#
# Epoch 43/99
# ----------
# Train Loss: 1.8796 Train Acc: 0.2714
# Val Loss: 2.0255 Val Acc: 0.2163
#
# Epoch 44/99
# ----------
# Train Loss: 1.8683 Train Acc: 0.2789
# Val Loss: 2.0292 Val Acc: 0.2163
#
# Epoch 45/99
# ----------
# Train Loss: 1.8508 Train Acc: 0.3049
# Val Loss: 2.0336 Val Acc: 0.2087
#
# Epoch 46/99
# ----------
# Train Loss: 1.8758 Train Acc: 0.2865
# Val Loss: 2.0301 Val Acc: 0.2061
#
# Epoch 47/99
# ----------
# Train Loss: 1.8583 Train Acc: 0.2876
# Val Loss: 2.0304 Val Acc: 0.2112
#
# Epoch 48/99
# ----------
# Train Loss: 1.8798 Train Acc: 0.2692
# Val Loss: 2.0312 Val Acc: 0.2214
#
# Epoch 49/99
# ----------
# Train Loss: 1.8525 Train Acc: 0.2995
# Val Loss: 2.0324 Val Acc: 0.2112
#
# Epoch 50/99
# ----------
# Train Loss: 1.8742 Train Acc: 0.2973
# Val Loss: 2.0300 Val Acc: 0.2188
#
# Epoch 51/99
# ----------
# Train Loss: 1.8640 Train Acc: 0.2757
# Val Loss: 2.0298 Val Acc: 0.2214
#
# Epoch 52/99
# ----------
# Train Loss: 1.8687 Train Acc: 0.2962
# Val Loss: 2.0329 Val Acc: 0.2188
#
# Epoch 53/99
# ----------
# Train Loss: 1.8827 Train Acc: 0.2735
# Val Loss: 2.0286 Val Acc: 0.2290
#
# Epoch 54/99
# ----------
# Train Loss: 1.8643 Train Acc: 0.2973
# Val Loss: 2.0280 Val Acc: 0.2061
#
# Epoch 55/99
# ----------
# Train Loss: 1.8764 Train Acc: 0.2703
# Val Loss: 2.0275 Val Acc: 0.2137
#
# Epoch 56/99
# ----------
# Train Loss: 1.8600 Train Acc: 0.2886
# Val Loss: 2.0317 Val Acc: 0.2163
#
# Epoch 57/99
# ----------
# Train Loss: 1.8689 Train Acc: 0.2832
# Val Loss: 2.0302 Val Acc: 0.2112
#
# Epoch 58/99
# ----------
# Train Loss: 1.8714 Train Acc: 0.2757
# Val Loss: 2.0305 Val Acc: 0.2112
#
# Epoch 59/99
# ----------
# Train Loss: 1.8722 Train Acc: 0.3027
# Val Loss: 2.0283 Val Acc: 0.2163
#
# Epoch 60/99
# ----------
# Train Loss: 1.8773 Train Acc: 0.2908
# Val Loss: 2.0330 Val Acc: 0.2112
#
# Epoch 61/99
# ----------
# Train Loss: 1.8799 Train Acc: 0.2843
# Val Loss: 2.0282 Val Acc: 0.2188
#
# Epoch 62/99
# ----------
# Train Loss: 1.8696 Train Acc: 0.3038
# Val Loss: 2.0300 Val Acc: 0.2188
#
# Epoch 63/99
# ----------
# Train Loss: 1.8731 Train Acc: 0.2800
# Val Loss: 2.0322 Val Acc: 0.2112
#
# Epoch 64/99
# ----------
# Train Loss: 1.8887 Train Acc: 0.2768
# Val Loss: 2.0293 Val Acc: 0.2188
#
# Epoch 65/99
# ----------
# Train Loss: 1.8754 Train Acc: 0.2714
# Val Loss: 2.0367 Val Acc: 0.2087
#
# Epoch 66/99
# ----------
# Train Loss: 1.8831 Train Acc: 0.2724
# Val Loss: 2.0320 Val Acc: 0.2112
#
# Epoch 67/99
# ----------
# Train Loss: 1.8653 Train Acc: 0.3038
# Val Loss: 2.0364 Val Acc: 0.2087
#
# Epoch 68/99
# ----------
# Train Loss: 1.8619 Train Acc: 0.2519
# Val Loss: 2.0271 Val Acc: 0.2112
#
# Epoch 69/99
# ----------
# Train Loss: 1.8883 Train Acc: 0.2616
# Val Loss: 2.0323 Val Acc: 0.2214
#
# Epoch 70/99
# ----------
# Train Loss: 1.8521 Train Acc: 0.3146
# Val Loss: 2.0293 Val Acc: 0.2137
#
# Epoch 71/99
# ----------
# Train Loss: 1.8513 Train Acc: 0.3038
# Val Loss: 2.0313 Val Acc: 0.2163
#
# Epoch 72/99
# ----------
# Train Loss: 1.8714 Train Acc: 0.2714
# Val Loss: 2.0341 Val Acc: 0.2087
#
# Epoch 73/99
# ----------
# Train Loss: 1.8648 Train Acc: 0.2822
# Val Loss: 2.0324 Val Acc: 0.2214
#
# Epoch 74/99
# ----------
# Train Loss: 1.8717 Train Acc: 0.2811
# Val Loss: 2.0299 Val Acc: 0.2265
#
# Epoch 75/99
# ----------
# Train Loss: 1.8593 Train Acc: 0.2865
# Val Loss: 2.0302 Val Acc: 0.2137
#
# Epoch 76/99
# ----------
# Train Loss: 1.8507 Train Acc: 0.2995
# Val Loss: 2.0264 Val Acc: 0.2188
#
# Epoch 77/99
# ----------
# Train Loss: 1.8643 Train Acc: 0.2886
# Val Loss: 2.0350 Val Acc: 0.2061
#
# Epoch 78/99
# ----------
# Train Loss: 1.8606 Train Acc: 0.2822
# Val Loss: 2.0334 Val Acc: 0.2112
#
# Epoch 79/99
# ----------
# Train Loss: 1.8581 Train Acc: 0.3081
# Val Loss: 2.0287 Val Acc: 0.2112
#
# Epoch 80/99
# ----------
# Train Loss: 1.8653 Train Acc: 0.2638
# Val Loss: 2.0296 Val Acc: 0.2239
#
# Epoch 81/99
# ----------
# Train Loss: 1.8838 Train Acc: 0.2746
# Val Loss: 2.0342 Val Acc: 0.2061
#
# Epoch 82/99
# ----------
# Train Loss: 1.8595 Train Acc: 0.2822
# Val Loss: 2.0319 Val Acc: 0.2188
#
# Epoch 83/99
# ----------
# Train Loss: 1.8624 Train Acc: 0.2865
# Val Loss: 2.0303 Val Acc: 0.2137
#
# Epoch 84/99
# ----------
# Train Loss: 1.8606 Train Acc: 0.2995
# Val Loss: 2.0298 Val Acc: 0.2137
#
# Epoch 85/99
# ----------
# Train Loss: 1.8722 Train Acc: 0.2800
# Val Loss: 2.0285 Val Acc: 0.2137
#
# Epoch 86/99
# ----------
# Train Loss: 1.8763 Train Acc: 0.2843
# Val Loss: 2.0339 Val Acc: 0.2112
#
# Epoch 87/99
# ----------
# Train Loss: 1.8706 Train Acc: 0.2789
# Val Loss: 2.0321 Val Acc: 0.2112
#
# Epoch 88/99
# ----------
# Train Loss: 1.8553 Train Acc: 0.2941
# Val Loss: 2.0309 Val Acc: 0.2137
#
# Epoch 89/99
# ----------
# Train Loss: 1.8831 Train Acc: 0.2951
# Val Loss: 2.0306 Val Acc: 0.2214
#
# Epoch 90/99
# ----------
# Train Loss: 1.8535 Train Acc: 0.3005
# Val Loss: 2.0324 Val Acc: 0.2112
#
# Epoch 91/99
# ----------
# Train Loss: 1.8626 Train Acc: 0.2941
# Val Loss: 2.0315 Val Acc: 0.2137
#
# Epoch 92/99
# ----------
# Train Loss: 1.8694 Train Acc: 0.2919
# Val Loss: 2.0318 Val Acc: 0.2036
#
# Epoch 93/99
# ----------
# Train Loss: 1.8595 Train Acc: 0.2919
# Val Loss: 2.0328 Val Acc: 0.2087
#
# Epoch 94/99
# ----------
# Train Loss: 1.8769 Train Acc: 0.2865
# Val Loss: 2.0273 Val Acc: 0.2112
#
# Epoch 95/99
# ----------
# Train Loss: 1.8765 Train Acc: 0.2768
# Val Loss: 2.0271 Val Acc: 0.2163
#
# Epoch 96/99
# ----------
# Train Loss: 1.8517 Train Acc: 0.2886
# Val Loss: 2.0275 Val Acc: 0.2163
#
# Epoch 97/99
# ----------
# Train Loss: 1.8706 Train Acc: 0.2811
# Val Loss: 2.0284 Val Acc: 0.2163
#
# Epoch 98/99
# ----------
# Train Loss: 1.8714 Train Acc: 0.2843
# Val Loss: 2.0340 Val Acc: 0.2036
#
# Epoch 99/99
# ----------
# Train Loss: 1.8724 Train Acc: 0.2832
# Val Loss: 2.0309 Val Acc: 0.2214
#
# Training complete in 10m 3s
# Best val Acc: 0.251908

# %%
# Plot the learning curves

train_acc = np.array([t.cpu().numpy() for t in train_acc])
val_acc = np.array([t.cpu().numpy() for t in val_acc])

print(f"Mean Train Accuracy: {np.mean(train_acc)}")
print(f"Mean Val Accuracy: {np.mean(val_acc)}")
print(f"Mean Train Loss: {np.mean(train_loss)}")
print(f"Mean Val Loss: {np.mean(val_loss)}")


plot_learning_curves(train_loss, train_acc, val_loss, val_acc)
# Out:
# Mean Train Accuracy: 0.28537297297297304
# Mean Val Accuracy: 0.21435114503816796
# Mean Train Loss: 1.868527559517525
# Mean Val Loss: 2.0303228498020855

# %%
from torchvision import models

model_ft = models.mobilenet_v2(pretrained=True)
num_ftrs = model_ft.classifier[1].in_features

# Replace classifier
model_ft.classifier = nn.Sequential(
    nn.Dropout(p=0.6),
    nn.Linear(num_ftrs, 9)  # Your number of classes
)
for param in model_ft.parameters():
    param.requires_grad = False

for param in model_ft.classifier.parameters():
    param.requires_grad = True
criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

for name, param in model_ft.features[-5:].named_parameters():  # last few blocks
    param.requires_grad = True



optimizer_ft = optim.Adam([
    {'params': model_ft.classifier.parameters(), 'lr': 1e-3},
    {'params': model_ft.features[-5:].parameters(), 'lr': 1e-5}
], weight_decay=1e-4)

model_ft = model_ft.to(device)

exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer_ft, mode='min', factor=0.5, patience=3, verbose=True)

# %%
### Train the model
model_ft, train_loss, train_acc, val_loss, val_acc = train_model(
    model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100, train_loader=train_loader, val_loader=val_loader
)
# Out:
# Epoch 0/99
# ----------
# Train Loss: 1.7197 Train Acc: 0.3395
# Val Loss: 2.1712 Val Acc: 0.3181
#
# Epoch 1/99
# ----------
# Train Loss: 1.6886 Train Acc: 0.3546
# Val Loss: 2.1705 Val Acc: 0.3003
#
# Epoch 2/99
# ----------
# Train Loss: 1.6539 Train Acc: 0.3773
# Val Loss: 2.2054 Val Acc: 0.3104
#
# Epoch 3/99
# ----------
# Train Loss: 1.6703 Train Acc: 0.3686
# Val Loss: 2.1817 Val Acc: 0.3079
#
# Epoch 4/99
# ----------
# Train Loss: 1.6378 Train Acc: 0.3654
# Val Loss: 2.2357 Val Acc: 0.3104
#
# Epoch 5/99
# ----------
# Train Loss: 1.6193 Train Acc: 0.3719
# Val Loss: 2.2068 Val Acc: 0.3130
#
# Epoch 6/99
# ----------
# Train Loss: 1.6184 Train Acc: 0.4086
# Val Loss: 2.2050 Val Acc: 0.3155
#
# Epoch 7/99
# ----------
# Train Loss: 1.6007 Train Acc: 0.3903
# Val Loss: 2.2252 Val Acc: 0.3155
#
# Epoch 8/99
# ----------
# Train Loss: 1.5807 Train Acc: 0.3914
# Val Loss: 2.2302 Val Acc: 0.3130
#
# Epoch 9/99
# ----------
# Train Loss: 1.6317 Train Acc: 0.3665
# Val Loss: 2.2197 Val Acc: 0.3130
#
# Epoch 10/99
# ----------
# Train Loss: 1.6055 Train Acc: 0.3989
# Val Loss: 2.2137 Val Acc: 0.3104
#
# Epoch 11/99
# ----------
# Train Loss: 1.5710 Train Acc: 0.4173
# Val Loss: 2.2060 Val Acc: 0.3130
#
# Epoch 12/99
# ----------
# Train Loss: 1.5855 Train Acc: 0.3903
# Val Loss: 2.2202 Val Acc: 0.3104
#
# Epoch 13/99
# ----------
# Train Loss: 1.6005 Train Acc: 0.3914
# Val Loss: 2.2203 Val Acc: 0.3079
#
# Epoch 14/99
# ----------
# Train Loss: 1.6060 Train Acc: 0.3719
# Val Loss: 2.2340 Val Acc: 0.3104
#
# Epoch 15/99
# ----------
# Train Loss: 1.5906 Train Acc: 0.4000
# Val Loss: 2.2227 Val Acc: 0.3104
#
# Epoch 16/99
# ----------
# Train Loss: 1.5961 Train Acc: 0.3978
# Val Loss: 2.2319 Val Acc: 0.3130
#
# Epoch 17/99
# ----------
# Train Loss: 1.5922 Train Acc: 0.3957
# Val Loss: 2.2214 Val Acc: 0.3130
#
# Epoch 18/99
# ----------
# Train Loss: 1.5786 Train Acc: 0.3914
# Val Loss: 2.2244 Val Acc: 0.3104
#
# Epoch 19/99
# ----------
# Train Loss: 1.6112 Train Acc: 0.3838
# Val Loss: 2.2079 Val Acc: 0.3104
#
# Epoch 20/99
# ----------
# Train Loss: 1.5844 Train Acc: 0.4097
# Val Loss: 2.2052 Val Acc: 0.3104
#
# Epoch 21/99
# ----------
# Train Loss: 1.5701 Train Acc: 0.3989
# Val Loss: 2.2167 Val Acc: 0.3104
#
# Epoch 22/99
# ----------
# Train Loss: 1.5893 Train Acc: 0.3989
# Val Loss: 2.2188 Val Acc: 0.3104
#
# Epoch 23/99
# ----------
# Train Loss: 1.5869 Train Acc: 0.4000
# Val Loss: 2.2186 Val Acc: 0.3104
#
# Epoch 24/99
# ----------
# Train Loss: 1.5826 Train Acc: 0.3838
# Val Loss: 2.2181 Val Acc: 0.3104
#
# Epoch 25/99
# ----------
# Train Loss: 1.5856 Train Acc: 0.4097
# Val Loss: 2.2192 Val Acc: 0.3104
#
# Epoch 26/99
# ----------
# Train Loss: 1.5868 Train Acc: 0.4054
# Val Loss: 2.2266 Val Acc: 0.3104
#
# Epoch 27/99
# ----------
# Train Loss: 1.5989 Train Acc: 0.4011
# Val Loss: 2.2317 Val Acc: 0.3079
#
# Epoch 28/99
# ----------
# Train Loss: 1.6024 Train Acc: 0.3914
# Val Loss: 2.2161 Val Acc: 0.3079
#
# Epoch 29/99
# ----------
# Train Loss: 1.6006 Train Acc: 0.3741
# Val Loss: 2.2291 Val Acc: 0.3104
#
# Epoch 30/99
# ----------
# Train Loss: 1.5936 Train Acc: 0.3914
# Val Loss: 2.2202 Val Acc: 0.3104
#
# Epoch 31/99
# ----------
# Train Loss: 1.5861 Train Acc: 0.3859
# Val Loss: 2.2220 Val Acc: 0.3104
#
# Epoch 32/99
# ----------
# Train Loss: 1.6071 Train Acc: 0.3859
# Val Loss: 2.2353 Val Acc: 0.3104
#
# Epoch 33/99
# ----------
# Train Loss: 1.5861 Train Acc: 0.4108
# Val Loss: 2.2235 Val Acc: 0.3104
#
# Epoch 34/99
# ----------
# Train Loss: 1.5862 Train Acc: 0.3849
# Val Loss: 2.2219 Val Acc: 0.3104
#
# Epoch 35/99
# ----------
# Train Loss: 1.6027 Train Acc: 0.3697
# Val Loss: 2.2185 Val Acc: 0.3104
#
# Epoch 36/99
# ----------
# Train Loss: 1.5912 Train Acc: 0.3708
# Val Loss: 2.2207 Val Acc: 0.3104
#
# Epoch 37/99
# ----------
# Train Loss: 1.5889 Train Acc: 0.3968
# Val Loss: 2.2156 Val Acc: 0.3104
#
# Epoch 38/99
# ----------
# Train Loss: 1.6156 Train Acc: 0.3827
# Val Loss: 2.2245 Val Acc: 0.3104
#
# Epoch 39/99
# ----------
# Train Loss: 1.5854 Train Acc: 0.4032
# Val Loss: 2.2249 Val Acc: 0.3104
#
# Epoch 40/99
# ----------
# Train Loss: 1.5809 Train Acc: 0.3892
# Val Loss: 2.2152 Val Acc: 0.3104
#
# Epoch 41/99
# ----------
# Train Loss: 1.5995 Train Acc: 0.3827
# Val Loss: 2.2337 Val Acc: 0.3104
#
# Epoch 42/99
# ----------
# Train Loss: 1.6062 Train Acc: 0.3784
# Val Loss: 2.2285 Val Acc: 0.3104
#
# Epoch 43/99
# ----------
# Train Loss: 1.6293 Train Acc: 0.3730
# Val Loss: 2.2255 Val Acc: 0.3104
#
# Epoch 44/99
# ----------
# Train Loss: 1.5976 Train Acc: 0.3892
# Val Loss: 2.2178 Val Acc: 0.3104
#
# Epoch 45/99
# ----------
# Train Loss: 1.5846 Train Acc: 0.3946
# Val Loss: 2.2295 Val Acc: 0.3130
#
# Epoch 46/99
# ----------
# Train Loss: 1.5654 Train Acc: 0.4065
# Val Loss: 2.2211 Val Acc: 0.3155
#
# Epoch 47/99
# ----------
# Train Loss: 1.5851 Train Acc: 0.3741
# Val Loss: 2.2312 Val Acc: 0.3130
#
# Epoch 48/99
# ----------
# Train Loss: 1.5774 Train Acc: 0.4086
# Val Loss: 2.2287 Val Acc: 0.3079
#
# Epoch 49/99
# ----------
# Train Loss: 1.6137 Train Acc: 0.3773
# Val Loss: 2.2191 Val Acc: 0.3104
#
# Epoch 50/99
# ----------
# Train Loss: 1.6116 Train Acc: 0.3881
# Val Loss: 2.2154 Val Acc: 0.3104
#
# Epoch 51/99
# ----------
# Train Loss: 1.5912 Train Acc: 0.3859
# Val Loss: 2.2313 Val Acc: 0.3130
#
# Epoch 52/99
# ----------
# Train Loss: 1.6019 Train Acc: 0.3870
# Val Loss: 2.2245 Val Acc: 0.3104
#
# Epoch 53/99
# ----------
# Train Loss: 1.6386 Train Acc: 0.3903
# Val Loss: 2.2265 Val Acc: 0.3130
#
# Epoch 54/99
# ----------
# Train Loss: 1.6045 Train Acc: 0.3870
# Val Loss: 2.2205 Val Acc: 0.3104
#
# Epoch 55/99
# ----------
# Train Loss: 1.5933 Train Acc: 0.3838
# Val Loss: 2.2262 Val Acc: 0.3104
#
# Epoch 56/99
# ----------
# Train Loss: 1.5790 Train Acc: 0.4097
# Val Loss: 2.2165 Val Acc: 0.3104
#
# Epoch 57/99
# ----------
# Train Loss: 1.5970 Train Acc: 0.3870
# Val Loss: 2.2284 Val Acc: 0.3104
#
# Epoch 58/99
# ----------
# Train Loss: 1.6204 Train Acc: 0.3935
# Val Loss: 2.2226 Val Acc: 0.3104
#
# Epoch 59/99
# ----------
# Train Loss: 1.6139 Train Acc: 0.3914
# Val Loss: 2.2214 Val Acc: 0.3104
#
# Epoch 60/99
# ----------
# Train Loss: 1.6192 Train Acc: 0.3751
# Val Loss: 2.2233 Val Acc: 0.3104
#
# Epoch 61/99
# ----------
# Train Loss: 1.5833 Train Acc: 0.4011
# Val Loss: 2.2235 Val Acc: 0.3130
#
# Epoch 62/99
# ----------
# Train Loss: 1.5964 Train Acc: 0.3859
# Val Loss: 2.2321 Val Acc: 0.3104
#
# Epoch 63/99
# ----------
# Train Loss: 1.6023 Train Acc: 0.3968
# Val Loss: 2.2195 Val Acc: 0.3104
#
# Epoch 64/99
# ----------
# Train Loss: 1.5708 Train Acc: 0.4184
# Val Loss: 2.2190 Val Acc: 0.3104
#
# Epoch 65/99
# ----------
# Train Loss: 1.5716 Train Acc: 0.3870
# Val Loss: 2.2264 Val Acc: 0.3104
#
# Epoch 66/99
# ----------
# Train Loss: 1.5967 Train Acc: 0.3881
# Val Loss: 2.2289 Val Acc: 0.3079
#
# Epoch 67/99
# ----------
# Train Loss: 1.6158 Train Acc: 0.3870
# Val Loss: 2.2230 Val Acc: 0.3079
#
# Epoch 68/99
# ----------
# Train Loss: 1.6024 Train Acc: 0.3741
# Val Loss: 2.2150 Val Acc: 0.3104
#
# Epoch 69/99
# ----------
# Train Loss: 1.5953 Train Acc: 0.3935
# Val Loss: 2.2175 Val Acc: 0.3079
#
# Epoch 70/99
# ----------
# Train Loss: 1.5846 Train Acc: 0.4054
# Val Loss: 2.2194 Val Acc: 0.3079
#
# Epoch 71/99
# ----------
# Train Loss: 1.6154 Train Acc: 0.3816
# Val Loss: 2.2181 Val Acc: 0.3104
#
# Epoch 72/99
# ----------
# Train Loss: 1.5929 Train Acc: 0.3978
# Val Loss: 2.2087 Val Acc: 0.3079
#
# Epoch 73/99
# ----------
# Train Loss: 1.5874 Train Acc: 0.4065
# Val Loss: 2.2238 Val Acc: 0.3104
#
# Epoch 74/99
# ----------
# Train Loss: 1.5722 Train Acc: 0.3914
# Val Loss: 2.2297 Val Acc: 0.3104
#
# Epoch 75/99
# ----------
# Train Loss: 1.5820 Train Acc: 0.3978
# Val Loss: 2.2218 Val Acc: 0.3104
#
# Epoch 76/99
# ----------
# Train Loss: 1.5899 Train Acc: 0.3935
# Val Loss: 2.2300 Val Acc: 0.3104
#
# Epoch 77/99
# ----------
# Train Loss: 1.5890 Train Acc: 0.4130
# Val Loss: 2.2340 Val Acc: 0.3130
#
# Epoch 78/99
# ----------
# Train Loss: 1.6072 Train Acc: 0.3957
# Val Loss: 2.2211 Val Acc: 0.3079
#
# Epoch 79/99
# ----------
# Train Loss: 1.5784 Train Acc: 0.3914
# Val Loss: 2.2221 Val Acc: 0.3104
#
# Epoch 80/99
# ----------
# Train Loss: 1.5764 Train Acc: 0.3957
# Val Loss: 2.2178 Val Acc: 0.3104
#
# Epoch 81/99
# ----------
# Train Loss: 1.5815 Train Acc: 0.4000
# Val Loss: 2.2242 Val Acc: 0.3104
#
# Epoch 82/99
# ----------
# Train Loss: 1.5784 Train Acc: 0.3838
# Val Loss: 2.2244 Val Acc: 0.3104
#
# Epoch 83/99
# ----------
# Train Loss: 1.5734 Train Acc: 0.4054
# Val Loss: 2.2339 Val Acc: 0.3104
#
# Epoch 84/99
# ----------
# Train Loss: 1.6276 Train Acc: 0.3632
# Val Loss: 2.2265 Val Acc: 0.3104
#
# Epoch 85/99
# ----------
# Train Loss: 1.5820 Train Acc: 0.3957
# Val Loss: 2.2301 Val Acc: 0.3130
#
# Epoch 86/99
# ----------
# Train Loss: 1.6013 Train Acc: 0.3741
# Val Loss: 2.2224 Val Acc: 0.3104
#
# Epoch 87/99
# ----------
# Train Loss: 1.6034 Train Acc: 0.3795
# Val Loss: 2.2244 Val Acc: 0.3104
#
# Epoch 88/99
# ----------
# Train Loss: 1.6054 Train Acc: 0.3881
# Val Loss: 2.2296 Val Acc: 0.3130
#
# Epoch 89/99
# ----------
# Train Loss: 1.5967 Train Acc: 0.3762
# Val Loss: 2.2289 Val Acc: 0.3104
#
# Epoch 90/99
# ----------
# Train Loss: 1.6107 Train Acc: 0.3914
# Val Loss: 2.2330 Val Acc: 0.3130
#
# Epoch 91/99
# ----------
# Train Loss: 1.6206 Train Acc: 0.4108
# Val Loss: 2.2161 Val Acc: 0.3079
#
# Epoch 92/99
# ----------
# Train Loss: 1.5837 Train Acc: 0.3924
# Val Loss: 2.2281 Val Acc: 0.3104
#
# Epoch 93/99
# ----------
# Train Loss: 1.5778 Train Acc: 0.4086
# Val Loss: 2.2304 Val Acc: 0.3104
#
# Epoch 94/99
# ----------
# Train Loss: 1.6183 Train Acc: 0.3827
# Val Loss: 2.2240 Val Acc: 0.3104
#
# Epoch 95/99
# ----------
# Train Loss: 1.6179 Train Acc: 0.3892
# Val Loss: 2.2225 Val Acc: 0.3104
#
# Epoch 96/99
# ----------
# Train Loss: 1.5659 Train Acc: 0.4097
# Val Loss: 2.2272 Val Acc: 0.3104
#
# Epoch 97/99
# ----------
# Train Loss: 1.6156 Train Acc: 0.3859
# Val Loss: 2.2262 Val Acc: 0.3104
#
# Epoch 98/99
# ----------
# Train Loss: 1.5926 Train Acc: 0.3859
# Val Loss: 2.2215 Val Acc: 0.3104
#
# Epoch 99/99
# ----------
# Train Loss: 1.6069 Train Acc: 0.3827
# Val Loss: 2.2234 Val Acc: 0.3104
#
# Training complete in 9m 59s
# Best val Acc: 0.318066

# %%
# Plot the learning curves

train_acc = np.array([t.cpu().numpy() for t in train_acc])
val_acc = np.array([t.cpu().numpy() for t in val_acc])

print(f"Mean Train Accuracy: {np.mean(train_acc)}")
print(f"Mean Val Accuracy: {np.mean(val_acc)}")
print(f"Mean Train Loss: {np.mean(train_loss)}")
print(f"Mean Val Loss: {np.mean(val_loss)}")


plot_learning_curves(train_loss, train_acc, val_loss, val_acc)
# Out:
# Mean Train Accuracy: 0.3898702702702703
# Mean Val Accuracy: 0.3106361323155216
# Mean Train Loss: 1.5996828838876775
# Mean Val Loss: 2.2213642687409285

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#save

import numpy as np

np.save("content/drive/train_accuracy_8.npy", train_acc)
np.save("/content/drive/val_accuracy_8.npy", val_acc)
# train_acc = np.load("model_results/train_accuracy_8.npy")
# val_acc = np.load("model_results/val_accuracy_8.npy")
torch.save(model_ft.state_dict(), "/content/drive/resnet50_medicine_classifier_8.pt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-140-1310066850.py in <cell line: 0>()
#       3 import numpy as np
#       4
# ----> 5 np.save("content/drive/train_accuracy_8.npy", train_acc)
#       6 np.save("/content/drive/val_accuracy_8.npy", val_acc)
#       7 # train_acc = np.load("model_results/train_accuracy_8.npy")
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_npyio_impl.py in save(file, arr, allow_pickle, fix_imports)
#     568         if not file.endswith('.npy'):
#     569             file = file + '.npy'
# --> 570         file_ctx = open(file, "wb")
#     571
#     572     with file_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'content/drive/train_accuracy_8.npy'
